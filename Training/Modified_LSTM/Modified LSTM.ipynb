# %% [markdown]
# # Libraries

# %%
import os, re, glob, json, time, random
from pathlib import Path
from copy import deepcopy
from collections import Counter, defaultdict
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
try:
    from torch.amp import autocast, GradScaler
except Exception:
    from torch.cuda.amp import autocast, GradScaler
import matplotlib.pyplot as plt
from math import sqrt

# Getting model.py
import sys
BASE_PATH = Path.cwd().parents[1]
sys.path.append(str(BASE_PATH))

print("Added to sys.path:", BASE_PATH)
from model import build_modified_lstm

# Directories
if "__file__" in globals():
    BASE_DIR = Path(__file__).resolve().parents[2]
# If running in notebook
else:
    BASE_DIR = Path.cwd().parents[1]

print("BASE_DIR:", BASE_DIR)

DATASET_DIR = BASE_DIR / "Training" / "KEYPOINTS"
EXPORT_ROOT = BASE_DIR / "Training" / "Modified_LSTM" / "ModifiedLSTM_Exports"
BEST_DIR    = BASE_DIR / "Training" / "Modified_LSTM" / "ModifiedLSTM_best"

EXPORT_ROOT.mkdir(parents=True, exist_ok=True)
BEST_DIR.mkdir(parents=True, exist_ok=True)

print("Dataset exists:", DATASET_DIR.exists())
print("Total classes:", len([d for d in DATASET_DIR.iterdir() if d.is_dir()]))
# Out:
# Added to sys.path: c:\Users\ACER NITRO\Documents\GitHub\PD-FSL
# BASE_DIR: c:\Users\ACER NITRO\Documents\GitHub\PD-FSL
# Dataset exists: True
# Total classes: 27

# %% [markdown]
# # Configuration and Helpers

# %%
try:
    import psutil
except Exception:
    psutil = None

SEED = 2025
import numpy as np, torch, random, time, os
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Handle CUDA compatibility issues
try:
    if torch.cuda.is_available():
        torch.cuda.set_device(0)
        device = torch.device("cuda")
        # Test if CUDA actually works
        _ = torch.zeros(1).to(device)
    else:
        device = torch.device("cpu")
except Exception as cuda_error:
    print(f"[WARNING] CUDA error: {cuda_error}")
    print("[WARNING] Falling back to CPU")
    device = torch.device("cpu")

print(f"Using device: {device}")

RUN_STAMP = time.strftime("%Y%m%d-%H%M%S")
EXPORT_DIR = EXPORT_ROOT / "HybridLSTMGRU" / RUN_STAMP
EXPORT_DIR.mkdir(parents=True, exist_ok=True)

# Use the DATASET_DIR already set in the Libraries cell (no override needed)
# DATASET_DIR is already: BASE_DIR / "Training" / "KEYPOINTS"

CONFIG = {
    "DATA_DIRS": [str(DATASET_DIR)],
    "SEQUENCE_LENGTH": 48,
    "BATCH_SIZE": 16,
    "EPOCHS": 150,
    "LR": 3e-4,
    "WEIGHT_DECAY": 1e-4,
    "DROPOUT": 0.30,
    "PATIENCE": 10,
    "VAL_SPLIT": 0.15,
    "TEST_SPLIT": 0.15,
    "NORM_MODE": "none",
    "AUG_ON": True,
    "HIDDEN_SIZE": 256,
    "NUM_LAYERS": 2,
    "EXPORT_DIR": EXPORT_DIR,
    "BEST_DIR": BEST_DIR,
}

print("Dataset dir:", DATASET_DIR)
print("BEST_DIR:", BEST_DIR)

# Verify DATASET_DIR exists, try fallback if needed
if not DATASET_DIR.exists():
    fallback_dir = Path(CONFIG["DATA_DIRS"][0])
    if fallback_dir.exists():
        DATASET_DIR = fallback_dir
        CONFIG["DATA_DIRS"] = [str(DATASET_DIR)]
        print(f"Using fallback dataset dir: {DATASET_DIR}")
    else:
        raise FileNotFoundError(f"KEYPOINTS directory not found at {DATASET_DIR} or {fallback_dir}")

actions = sorted([d for d in os.listdir(DATASET_DIR) if os.path.isdir(os.path.join(DATASET_DIR, d))])
CONFIG["CLASSES"] = actions
print("Discovered classes:", CONFIG["CLASSES"])

# Should be same feature as our extraction
SELECT_JOINTS = [0, 4, 8, 12, 16, 20]
DERIVED_PER_JOINT = 5
DERIVED_DIM = len(SELECT_JOINTS) * 2 * DERIVED_PER_JOINT
BASE_HAND_DIM = 42 * 3
APPEND_FLAGS = True
FEATURE_DIM = BASE_HAND_DIM + DERIVED_DIM + (2 if APPEND_FLAGS else 0)  # 188 total
CONFIG["FEATURE_DIM"] = FEATURE_DIM

# flag indices
FLAG_START = FEATURE_DIM - 2
FLAG_END   = FEATURE_DIM
CONFIG["FLAG_START"] = FLAG_START
CONFIG["FLAG_END"]   = FLAG_END

print(f"Feature dimension set to {FEATURE_DIM} (flags at {FLAG_START}:{FLAG_END})")
# Out:
# Using device: cuda
# Dataset dir: c:\Users\ACER NITRO\Documents\GitHub\FSL-PROJECT-DESIGN\BETTER\Training\KEYPOINTS
# Discovered classes: ['Color_Black', 'Color_Blue', 'Color_Green', 'Color_Orange', 'Color_Pink', 'Color_Red', 'Color_White', 'Color_Yellow', 'Family_Daughter', 'Family_Father', 'Family_Grandfather', 'Family_Grandmother', 'Family_Mother', 'Family_Son', 'Numbers_Five', 'Numbers_Four', 'Numbers_One', 'Numbers_Three', 'Numbers_Two', 'Relationship_Boy', 'Relationship_Girl', 'Survival_Correct', "Survival_Don't Understand", 'Survival_No', 'Survival_Understand', 'Survival_Wrong', 'Survival_Yes']
# Feature dimension set to 188 (flags at 186:188)

# %%
# Helpers
def _next_run_id(dir_path, prefix="run"):
    """
    Scan dir for files or subfolders named like 'run<number>.*' or 'run<number>'.
    Returns the next integer id (starting at 1).
    """
    p = Path(dir_path)
    p.mkdir(parents=True, exist_ok=True)
    pat = re.compile(rf"^{re.escape(prefix)}(\d+)")
    seen = []
    for item in p.iterdir():
        m = pat.match(item.stem)  
        if m:
            try:
                seen.append(int(m.group(1)))
            except ValueError:
                pass
    return (max(seen) + 1) if seen else 1

def _latest_run_id(dir_path, prefix="run"):
    p = Path(dir_path)
    if not p.exists():
        return None
    pat = re.compile(rf"^{re.escape(prefix)}(\d+)")
    seen = []
    for item in p.iterdir():
        m = pat.match(item.stem)
        if m:
            try:
                seen.append(int(m.group(1)))
            except ValueError:
                pass
    return max(seen) if seen else None

# Ensure directory exists
Path(CONFIG["BEST_DIR"]).mkdir(parents=True, exist_ok=True)
RUN_PREFIX = "run"

def _find_latest_run_id(dir_path, prefix=RUN_PREFIX):
    latest = _latest_run_id(dir_path, prefix)
    return latest if latest is not None else 0  # 0 means none yet

CURRENT_RUN_ID = _find_latest_run_id(CONFIG["BEST_DIR"], prefix=RUN_PREFIX)

SKIP_VIDEO_TESTS = False

class Chrono:
    def __enter__(self): 
        self.t0 = time.time(); 
        return self
    def __exit__(self, *exc): 
        self.dt = time.time() - self.t0

def human_time(sec):
    m, s = divmod(int(sec), 60); h, m = divmod(m, 60)
    return f"{h:d}h {m:02d}m {s:02d}s" if h else (f"{m:d}m {s:02d}s" if m else f"{s:d}s")

def report_memory(prefix=""):
    gpu_mem = None
    if torch.cuda.is_available():
        torch.cuda.synchronize()
        gpu_mem = torch.cuda.memory_allocated() / (1024**2)
    ram = psutil.Process().memory_info().rss / (1024**2) if psutil else None
    msg = []
    if ram is not None: msg.append(f"RAM: {ram:.1f} MB")
    if gpu_mem is not None: msg.append(f"GPU: {gpu_mem:.1f} MB")
    print((prefix+" ").strip(), " | ".join(msg))

report_memory("Init mem")
print(f"Exports will be saved to: {CONFIG['EXPORT_DIR']}")
# Out:
# Init mem RAM: 729.2 MB | GPU: 0.0 MB
# Exports will be saved to: c:\Users\ACER NITRO\Documents\GitHub\FSL-PROJECT-DESIGN\BETTER\Training\Modified_LSTM\ModifiedLSTM_Exports\HybridLSTMGRU\20260302-225355

# %% [markdown]
# # Dataset

# %%
# Utilities
FLAG_START = CONFIG["FLAG_START"]
FLAG_END   = CONFIG["FLAG_END"]
FEATURE_DIM = CONFIG["FEATURE_DIM"]

def infer_label_from_path(path, classes):
    p = Path(path)
    for c in classes:
        if c in p.parts:
            return classes.index(c)
    stem = p.stem
    for c in classes:
        if stem.startswith(c):
            return classes.index(c)
    raise ValueError(f"Cannot infer label for {path}")

def list_npy_files(data_dirs):
    files = []
    for d in data_dirs:
        if not os.path.isdir(d): continue
        files.extend(glob.glob(str(Path(d) / "**" / "*.npy"), recursive=True))
    return sorted(files)

def effective_length(arr):
    T, D = arr.shape
    if D >= FEATURE_DIM:
        flags = arr[:, FLAG_START:FLAG_END]
        valid = (flags.sum(axis=1) > 0.0)
        if valid.any(): return int(valid.sum())
    coords = arr[:, :min(BASE_HAND_DIM, D)].reshape(T, -1)
    if T <= 1:
        return 1 if np.abs(coords).sum() > 1e-6 else 0
    diffs = np.abs(np.diff(coords, axis=0)).reshape(T-1, -1)
    mag = diffs.mean(axis=1)
    eps = 1e-6
    active = np.zeros(T, dtype=bool)
    active[0] = (mag[0] > eps) if len(mag) else (np.abs(coords[0]).sum() > eps)
    active[1:] = mag > eps
    if active.any(): return int(active.sum())
    nonzero = (np.abs(coords).sum(axis=1) > 1e-6)
    return int(nonzero.sum()) if nonzero.any() else (T if coords.any() else 0)

def _presence_score(arr):
    T, D = arr.shape
    if D >= FEATURE_DIM:
        flags = arr[:, FLAG_START:FLAG_END]
        return ((flags[:,0] > 0.5) | (flags[:,1] > 0.5)).astype(np.float32)
    coords = arr[:, :min(BASE_HAND_DIM, D)]
    if T < 2:
        return (np.abs(coords).sum(axis=1) > 1e-6).astype(np.float32)
    diffs = np.linalg.norm(np.diff(coords, axis=0), axis=1)
    diffs = np.concatenate([[0.0], diffs])
    rng = diffs.ptp()
    return (diffs - diffs.min()) / (rng + 1e-6)

def _random_crop_start(arr, L):
    T = len(arr)
    if T <= L: return 0
    score = _presence_score(arr)
    k = T - L + 1
    window_scores = np.zeros(k, dtype=np.float32)
    csum = np.concatenate([[0.0], np.cumsum(score)])
    for s in range(k):
        window_scores[s] = csum[s+L] - csum[s]
    probs = window_scores + 1e-6
    probs /= probs.sum()
    return int(np.random.choice(np.arange(k), p=probs))

# %%
FLAG_START = CONFIG["FLAG_START"]
FLAG_END   = CONFIG["FLAG_END"]
FEATURE_DIM = CONFIG["FEATURE_DIM"]

# Data augmentation
def _resample(coords, flags, L):
    T = coords.shape[0]
    if T == L: return coords, flags
    idx = np.linspace(0, T-1, L)
    lo  = np.floor(idx).astype(int)
    hi  = np.clip(lo+1, 0, T-1)
    w   = (idx - lo)[:,None,None]
    c   = (1-w)*coords[lo] + w*coords[hi]
    f   = flags[np.round(idx).astype(int)]
    return c.astype(np.float32), f.astype(np.float32)

def temporal_shift(x, max_shift=3):
    if max_shift <= 0: return x
    T, D = x.shape
    s = np.random.randint(-max_shift, max_shift+1)
    if s == 0: return x
    pad = np.zeros((abs(s), D), np.float32)
    return (np.concatenate([pad, x], 0)[:T] if s > 0
            else np.concatenate([x[-s:], pad], 0)[:T])

def temporal_stretch(x, rmin=0.90, rmax=1.12):
    T, D = x.shape
    r = np.random.uniform(rmin, rmax)
    Lnew = max(8, int(round(T*r)))
    coords = x[:, :BASE_HAND_DIM].reshape(T, 42, 3)
    flags  = x[:, FLAG_START:FLAG_END] if D >= FEATURE_DIM else np.zeros((T, 2), np.float32)
    c, f = _resample(coords, flags, Lnew)
    y = np.zeros((T, D), np.float32)
    Lc = min(Lnew, T)
    y[:Lc, :BASE_HAND_DIM] = c.reshape(Lnew, BASE_HAND_DIM)[:Lc]
    if D >= FEATURE_DIM: y[:Lc, FLAG_START:FLAG_END] = f[:Lc]
    return y

def temporal_dropout(x, max_runs=1, run_len=(1, 2)):
    T, D = x.shape
    coords = x[:, :BASE_HAND_DIM].reshape(T, 42, 3)
    flags  = x[:, FLAG_START:FLAG_END] if D >= FEATURE_DIM else np.zeros((T, 2), np.float32)
    runs = np.random.randint(0, max_runs+1)
    for _ in range(runs):
        k = np.random.randint(run_len[0], run_len[1]+1)
        s = np.random.randint(0, max(1, T-k))
        coords[s:s+k] = 0.0
        if D >= FEATURE_DIM: flags[s:s+k] = 0.0
    x[:, :BASE_HAND_DIM] = coords.reshape(T, BASE_HAND_DIM)
    if D >= FEATURE_DIM: x[:, FLAG_START:FLAG_END] = flags
    return x

def spatial_jitter(x, rot_deg=7.0, scale_j=0.08, trans_j=0.03, noise_std=0.01):
    T, D = x.shape
    coords = x[:, :BASE_HAND_DIM].reshape(T, 42, 3)
    flags  = x[:, FLAG_START:FLAG_END] if D >= FEATURE_DIM else np.zeros((T, 2), np.float32)

    theta = np.deg2rad(np.random.uniform(-rot_deg, rot_deg))
    c, s = np.cos(theta), np.sin(theta)
    R = np.asarray([[c, -s], [s, c]], np.float32)
    sc = 1.0 + np.random.uniform(-scale_j, scale_j)
    tr = np.random.uniform(-trans_j, trans_j, size=(2,)).astype(np.float32)

    xy = coords[..., :2]
    present = (flags.sum(1) > 0.5)[:, None, None] if D >= FEATURE_DIM else np.ones((T,1,1),bool)
    xy = np.where(present, (xy @ R.T) * sc + tr, xy)
    coords[..., :2] = xy

    noise = np.random.normal(0.0, noise_std, size=coords.shape).astype(np.float32)
    coords = np.where(present, coords + noise, coords)

    x[:, :BASE_HAND_DIM] = coords.reshape(T, BASE_HAND_DIM)
    if D >= FEATURE_DIM: x[:, FLAG_START:FLAG_END] = flags
    return x

def random_augment(x):
    if np.random.rand() < 0.8: x = temporal_shift(x, 3)
    if np.random.rand() < 0.6: x = temporal_stretch(x, 0.90, 1.12)
    if np.random.rand() < 0.4: x = temporal_dropout(x, 1, (1, 2))
    if np.random.rand() < 0.7: x = spatial_jitter(x, 7.0, 0.08, 0.03, 0.01)
    return x

# %%
class KeypointSequenceDataset(Dataset):
    def __init__(self, files, classes, seq_len, split="train",
                 mean_vec=None, std_vec=None):
        self.files = files
        self.classes = classes
        self.seq_len = seq_len
        self.split = split
        self.mean_vec = mean_vec
        self.std_vec = std_vec

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        f = self.files[idx]
        arr = np.load(f).astype(np.float32)  # (T, D)
        T, D = arr.shape

        # normalize (optional)
        if CONFIG.get("NORM_MODE") == "zscore" and self.mean_vec is not None:
            arr = (arr - self.mean_vec) / self.std_vec

        # apply augmentation (only train)
        if self.split == "train" and CONFIG.get("AUG_ON", True):
            arr = random_augment(arr)

        # pad or trim
        L = self.seq_len
        if T > L:
            arr = arr[:L]
        elif T < L:
            pad = np.zeros((L - T, D), np.float32)
            arr = np.concatenate([arr, pad], axis=0)

        y = infer_label_from_path(f, self.classes)
        return {
            "x": torch.from_numpy(arr),
            "len": torch.tensor(min(T, L)),
            "y": torch.tensor(y, dtype=torch.long),
            "path": f,
        }


def collate_batch(samples):
    xs = torch.stack([s["x"] for s in samples])
    lens = torch.stack([s["len"] for s in samples])
    ys = torch.stack([s["y"] for s in samples])
    paths = [s["path"] for s in samples]
    return xs, lens, ys, paths

# %%
TEST_KEEP_AUG = False

FLAG_START = CONFIG["FLAG_START"]
FLAG_END   = CONFIG["FLAG_END"]
FEATURE_DIM = CONFIG["FEATURE_DIM"]

def base_group(path: str) -> str:
    p = Path(path)
    label = p.parent.name
    stem  = re.sub(r"_aug\d+$", "", p.stem, flags=re.IGNORECASE)
    return f"{label}::{stem}"

def is_augmented(path: str) -> bool:
    return bool(re.search(r"_aug\d+$", Path(path).stem.lower()))

all_files = list_npy_files(CONFIG["DATA_DIRS"])

usable, labels = [], []
for f in all_files:
    try:
        arr = np.load(f, mmap_mode='r')
        if arr.ndim == 2 and arr.shape[1] == FEATURE_DIM:
            usable.append(f)
            labels.append(infer_label_from_path(f, CONFIG["CLASSES"]))
    except Exception:
        pass

assert len(usable) > 0, f"No usable .npy found — expected feature dim {FEATURE_DIM}."
print(f"Total usable samples (pre-filter): {len(usable)}")

# Drop weak clips before splitting
MIN_ACTIVE = 6
M_THR      = 0.02

def motion_active_len(fp, m_thr=M_THR):
    a = np.load(fp)
    if a.ndim != 2 or a.shape[1] != FEATURE_DIM:
        return 0
    T, D = a.shape
    if T < 2: return 0
    coords = a[:, :BASE_HAND_DIM].reshape(T, 42, 3)
    v = np.diff(coords, axis=0)
    m = np.linalg.norm(v, axis=(1,2))
    rng = np.ptp(m)
    m = (m - m.min()) / (rng + 1e-6)
    return int((m > m_thr).sum())

usable_filtered = []
for f in usable:
    try:
        if motion_active_len(f) >= MIN_ACTIVE:
            usable_filtered.append(f)
    except Exception:
        pass

if len(usable_filtered) != len(usable):
    print(f"Filtered out {len(usable) - len(usable_filtered)} weak/idle clips.")
usable = usable_filtered
labels = [infer_label_from_path(f, CONFIG["CLASSES"]) for f in usable]

# build dataframe & group-aware splits
df = pd.DataFrame({"path": usable, "label": labels})
df["group"]  = df["path"].apply(base_group)
df["is_aug"] = df["path"].apply(is_augmented)

df_base = df[~df["is_aug"]].copy()
assert len(df_base) > 0, "No base files found."

grp_lbl_unique = df_base.groupby("group")["label"].nunique()
if not (grp_lbl_unique == 1).all():
    bad = grp_lbl_unique[grp_lbl_unique != 1]
    raise ValueError(f"Mixed labels within base groups: {bad.index.tolist()[:8]} ...")

group_labels_df = df_base.groupby("group")["label"].first().reset_index()
all_groups = group_labels_df["group"].tolist()
all_group_labels = group_labels_df["label"].tolist()

from sklearn.model_selection import train_test_split
TEST_SPLIT = CONFIG["TEST_SPLIT"]
VAL_SPLIT  = CONFIG["VAL_SPLIT"]

grp_trainval, grp_test = train_test_split(
    all_groups,
    test_size=TEST_SPLIT,
    stratify=all_group_labels,
    random_state=SEED
)

remain_mask   = group_labels_df["group"].isin(grp_trainval)
remain_groups = group_labels_df.loc[remain_mask, "group"].tolist()
remain_labels = group_labels_df.loc[remain_mask, "label"].tolist()

val_ratio_of_trainval = VAL_SPLIT / (1.0 - TEST_SPLIT)
grp_train, grp_val = train_test_split(
    remain_groups,
    test_size=val_ratio_of_trainval,
    stratify=remain_labels,
    random_state=SEED
)

grp_train, grp_val, grp_test = set(grp_train), set(grp_val), set(grp_test)

train_files = df[df["group"].isin(grp_train) & (~df["is_aug"])]["path"].tolist()
val_files   = df[df["group"].isin(grp_val)   & (~df["is_aug"])]["path"].tolist()
test_files  = df[df["group"].isin(grp_test)  & (~df["is_aug"])]["path"].tolist()
print("Split sizes (no group overlap):")
print("  Train:", len(train_files))
print("  Val:  ", len(val_files))
print("  Test: ", len(test_files))

def files_to_groups(files): return {base_group(p) for p in files}
assert set(train_files).isdisjoint(val_files)
assert set(train_files).isdisjoint(test_files)
assert set(val_files).isdisjoint(test_files)

def compute_feature_stats(paths, max_files=None):
    xs = []
    for i, f in enumerate(paths):
        if (max_files is not None) and (i >= max_files): break
        a = np.load(f).astype(np.float32)
        xs.append(a)
    X = np.concatenate(xs, axis=0) if len(xs) else np.zeros((1, FEATURE_DIM), np.float32)
    mv = X.mean(axis=0, dtype=np.float64).astype(np.float32)
    sv = X.std(axis=0,  dtype=np.float64).astype(np.float32)
    sv[sv < 1e-6] = 1.0
    return mv, sv

train_mean, train_std = compute_feature_stats(train_files)

train_ds = KeypointSequenceDataset(train_files, CONFIG["CLASSES"], CONFIG["SEQUENCE_LENGTH"],
                                   split="train", mean_vec=train_mean, std_vec=train_std)
val_ds   = KeypointSequenceDataset(val_files,   CONFIG["CLASSES"], CONFIG["SEQUENCE_LENGTH"],
                                   split="val",   mean_vec=train_mean, std_vec=train_std)
test_ds  = KeypointSequenceDataset(test_files,  CONFIG["CLASSES"], CONFIG["SEQUENCE_LENGTH"],
                                   split="test",  mean_vec=train_mean, std_vec=train_std)

train_loader = DataLoader(train_ds, batch_size=CONFIG["BATCH_SIZE"], shuffle=True,
                          collate_fn=collate_batch, num_workers=0, pin_memory=False,
                          persistent_workers=False)
val_loader   = DataLoader(val_ds,   batch_size=CONFIG["BATCH_SIZE"], shuffle=False,
                          collate_fn=collate_batch, num_workers=0, pin_memory=False,
                          persistent_workers=False)
test_loader  = DataLoader(test_ds,  batch_size=CONFIG["BATCH_SIZE"], shuffle=False,
                          collate_fn=collate_batch, num_workers=0, pin_memory=False,
                          persistent_workers=False)

cnt = Counter([infer_label_from_path(p, CONFIG["CLASSES"]) for p in train_files])
class_weights = torch.tensor([1.0/max(1, cnt[i]) for i in range(len(CONFIG["CLASSES"]))], dtype=torch.float32)
# Out:
# Total usable samples (pre-filter): 542
# Split sizes (no group overlap):
#   Train: 378
#   Val:   82
#   Test:  82

# %% [markdown]
# # Modified LSTM

# %%
INPUT_SIZE  = CONFIG["FEATURE_DIM"]
NUM_CLASSES = len(CONFIG["CLASSES"])

model = build_modified_lstm(NUM_CLASSES, input_size=INPUT_SIZE,
                            hidden_size=CONFIG["HIDDEN_SIZE"],
                            num_layers=CONFIG["NUM_LAYERS"],
                            dropout=CONFIG["DROPOUT"], use_layernorm=True)

model = model.to(device)

total_params = sum(p.numel() for p in model.parameters())
print(f"ModifiedLSTM params: {total_params/1e3:.1f}K  |  Input dim = {INPUT_SIZE}")
print(f"  hidden={CONFIG['HIDDEN_SIZE']}, layers={CONFIG['NUM_LAYERS']}, dropout={CONFIG['DROPOUT']}")
# Out:
# ModifiedLSTM params: 997.9K  |  Input dim = 188

# %%
FLAG_START = CONFIG["FLAG_START"]
FLAG_END   = CONFIG["FLAG_END"]

# === Training + Inference Time + Last-5 Avg + Model Size (MB) ===
def train_run(TRAIN_FROM_SCRATCH=True, prefix="run"):
    best_dir = Path(CONFIG["BEST_DIR"]); best_dir.mkdir(parents=True, exist_ok=True)

    run_id = _next_run_id(best_dir, prefix=prefix) if TRAIN_FROM_SCRATCH else _latest_run_id(best_dir, prefix=prefix) or 1
    ckpt_name, weights_name = f"{prefix}{run_id}.pt", f"{prefix}{run_id}.pth"
    ckpt_path, weights_path = best_dir / ckpt_name, best_dir / weights_name
    export_dir = Path(CONFIG["EXPORT_DIR"]) / f"{prefix}{run_id}"; export_dir.mkdir(parents=True, exist_ok=True)

    # Build model from CONFIG (no hardcoded sizes)
    _model = build_modified_lstm(
        len(CONFIG["CLASSES"]),
        input_size=CONFIG["FEATURE_DIM"],
        hidden_size=CONFIG.get("HIDDEN_SIZE", 256),
        num_layers=CONFIG.get("NUM_LAYERS", 2),
        dropout=CONFIG["DROPOUT"],
        use_layernorm=True
    ).to(device)

    print(f"Training for {CONFIG['EPOCHS']} epochs… ({prefix}{run_id})")
    print(f"  hidden={CONFIG.get('HIDDEN_SIZE', 256)}, layers={CONFIG.get('NUM_LAYERS', 2)}, dropout={CONFIG['DROPOUT']}")
    print(f"  Saving to: {best_dir}")

    criterion  = nn.CrossEntropyLoss(weight=class_weights.to(device), label_smoothing=0.05)
    optimizer  = torch.optim.Adam(_model.parameters(), lr=CONFIG["LR"], weight_decay=CONFIG["WEIGHT_DECAY"])
    scheduler  = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", factor=0.5, patience=5, min_lr=1e-5)
    use_cuda   = torch.cuda.is_available()
    scaler     = GradScaler(enabled=use_cuda)
    history = defaultdict(list)
    best_val_loss, best_epoch, no_improve = float("inf"), -1, 0

    def run_one_epoch(loader, train=True):
        _model.train(train)
        total_loss = 0; total = 0; correct = 0; inf_times = []
        for x, lens, y, _paths in loader:
            x, y = x.to(device).float(), y.to(device).long()
            reset_mask = (x[..., FLAG_START:FLAG_END].sum(dim=-1) > 0).float()
            if train: optimizer.zero_grad(set_to_none=True)
            with autocast(device_type="cuda", enabled=use_cuda):
                t0 = time.time()
                logits = _model(x, reset_mask=reset_mask)
                t1 = time.time()
                loss = criterion(logits, y)
            if not train: inf_times.append(t1 - t0)
            if train:
                if use_cuda:
                    scaler.scale(loss).backward()
                    scaler.unscale_(optimizer)
                    torch.nn.utils.clip_grad_norm_(_model.parameters(), max_norm=1.0)
                    scaler.step(optimizer); scaler.update()
                else:
                    loss.backward(); torch.nn.utils.clip_grad_norm_(_model.parameters(), max_norm=1.0); optimizer.step()
            with torch.no_grad():
                pred = logits.argmax(1)
                correct += (pred == y).sum().item(); total += y.size(0)
                total_loss += loss.item() * y.size(0)
        inf_ms = (np.mean(inf_times)*1000) if inf_times else 0
        return total_loss/max(1,total), correct/max(1,total), inf_ms

    print("\n=== Training started ===")
    t0 = time.time()
    for epoch in range(CONFIG["EPOCHS"]):
        tr_loss, tr_acc, _ = run_one_epoch(train_loader, True)
        with torch.no_grad():
            va_loss, va_acc, va_inf = run_one_epoch(val_loader, False)
        scheduler.step(va_loss)
        history["train_loss"].append(tr_loss); history["train_acc"].append(tr_acc)
        history["val_loss"].append(va_loss);   history["val_acc"].append(va_acc)
        history.setdefault("val_inf_time", []).append(va_inf)
        tag = ""
        if va_loss < best_val_loss - 1e-4:
            best_val_loss, best_epoch, no_improve = va_loss, epoch, 0
            torch.save(_model.state_dict(), weights_path)
            torch.save({
                "epoch": epoch, "model_state_dict": _model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "config": CONFIG, "best_val_loss": float(best_val_loss),
                "history": {k:[float(v) for v in vals] for k,vals in history.items()},
            }, ckpt_path)
            tag = f"  <-- BEST (saved {ckpt_name})"
        else:
            no_improve += 1
            if no_improve >= CONFIG["PATIENCE"]:
                print(f"Early stopping (no improve {CONFIG['PATIENCE']} epochs, best@{best_epoch})")
                break
        print(f"Epoch {epoch+1:03d} | train {tr_loss:.4f}/{tr_acc:.4f} | val {va_loss:.4f}/{va_acc:.4f} | inf {va_inf:.2f}ms{tag}")

    print("\n=== [SUMMARY] ===")
    print(f"Best epoch: {best_epoch}, best val loss: {best_val_loss:.4f}")
    print("========================")
    with open(export_dir / "train_history.json", "w") as f:
        json.dump({k:[float(v) for v in vls] for k,vls in history.items()}, f)

train_run(TRAIN_FROM_SCRATCH=True)
# Out:
# Training for 150 epochs… (run17)
#
# === Training started ===
# Epoch 001 | train 3.2336/0.1111 | val 3.0938/0.1585 | inf 4.97ms  <-- BEST (saved run17.pt)
# Epoch 002 | train 2.9614/0.2354 | val 2.8396/0.3293 | inf 4.10ms  <-- BEST (saved run17.pt)
# Epoch 003 | train 2.7096/0.3968 | val 2.5811/0.4878 | inf 4.32ms  <-- BEST (saved run17.pt)
# Epoch 004 | train 2.4584/0.5503 | val 2.3356/0.5610 | inf 3.18ms  <-- BEST (saved run17.pt)
# Epoch 005 | train 2.2224/0.6376 | val 2.1122/0.6220 | inf 3.93ms  <-- BEST (saved run17.pt)
# Epoch 006 | train 2.0063/0.7249 | val 1.9256/0.6829 | inf 12.22ms  <-- BEST (saved run17.pt)
# Epoch 007 | train 1.8053/0.7619 | val 1.7423/0.7439 | inf 3.08ms  <-- BEST (saved run17.pt)
# Epoch 008 | train 1.6294/0.8016 | val 1.5735/0.7317 | inf 3.82ms  <-- BEST (saved run17.pt)
# Epoch 009 | train 1.4703/0.8386 | val 1.4214/0.7927 | inf 3.48ms  <-- BEST (saved run17.pt)
# Epoch 010 | train 1.3448/0.8704 | val 1.3279/0.7927 | inf 5.35ms  <-- BEST (saved run17.pt)
# Epoch 011 | train 1.2366/0.8836 | val 1.2776/0.7805 | inf 5.27ms  <-- BEST (saved run17.pt)
# Epoch 012 | train 1.1377/0.9153 | val 1.1350/0.8659 | inf 3.94ms  <-- BEST (saved run17.pt)
# Epoch 013 | train 1.0429/0.9286 | val 1.0909/0.8293 | inf 3.01ms  <-- BEST (saved run17.pt)
# Epoch 014 | train 0.9617/0.9286 | val 0.9723/0.8902 | inf 5.54ms  <-- BEST (saved run17.pt)
# Epoch 015 | train 0.8924/0.9630 | val 0.9121/0.9146 | inf 3.00ms  <-- BEST (saved run17.pt)
# Epoch 016 | train 0.8370/0.9497 | val 0.8888/0.8780 | inf 6.16ms  <-- BEST (saved run17.pt)
# Epoch 017 | train 0.7695/0.9630 | val 0.8614/0.8902 | inf 3.53ms  <-- BEST (saved run17.pt)
# Epoch 018 | train 0.7658/0.9418 | val 0.7799/0.9268 | inf 3.30ms  <-- BEST (saved run17.pt)
# Epoch 019 | train 0.7100/0.9656 | val 0.7749/0.9268 | inf 3.26ms  <-- BEST (saved run17.pt)
# Epoch 020 | train 0.6602/0.9788 | val 0.7439/0.9146 | inf 5.83ms  <-- BEST (saved run17.pt)
# Epoch 021 | train 0.6538/0.9577 | val 0.7456/0.9146 | inf 4.79ms
# Epoch 022 | train 0.6207/0.9735 | val 0.6770/0.9146 | inf 5.51ms  <-- BEST (saved run17.pt)
# Epoch 023 | train 0.5768/0.9762 | val 0.7327/0.8902 | inf 3.36ms
# Epoch 024 | train 0.5765/0.9577 | val 0.7096/0.8902 | inf 3.01ms
# Epoch 025 | train 0.5373/0.9815 | val 0.5801/0.9512 | inf 7.03ms  <-- BEST (saved run17.pt)
# Epoch 026 | train 0.5067/0.9841 | val 0.6387/0.9146 | inf 3.90ms
# Epoch 027 | train 0.4895/0.9788 | val 0.5759/0.9268 | inf 2.83ms  <-- BEST (saved run17.pt)
# Epoch 028 | train 0.4659/0.9868 | val 0.6380/0.9024 | inf 4.80ms
# Epoch 029 | train 0.4787/0.9788 | val 0.6123/0.9146 | inf 5.25ms
# Epoch 030 | train 0.4623/0.9894 | val 0.5658/0.9268 | inf 3.80ms  <-- BEST (saved run17.pt)
# Epoch 031 | train 0.4424/0.9947 | val 0.6223/0.9024 | inf 3.46ms
# Epoch 032 | train 0.4329/0.9921 | val 0.5563/0.9268 | inf 4.69ms  <-- BEST (saved run17.pt)
# Epoch 033 | train 0.4282/0.9841 | val 0.6612/0.9146 | inf 3.12ms
# Epoch 034 | train 0.4632/0.9709 | val 0.6249/0.8902 | inf 12.08ms
# Epoch 035 | train 0.4609/0.9735 | val 0.5699/0.9268 | inf 11.02ms
# Epoch 036 | train 0.4511/0.9762 | val 0.5364/0.9268 | inf 13.40ms  <-- BEST (saved run17.pt)
# Epoch 037 | train 0.4179/0.9921 | val 0.5137/0.9512 | inf 12.10ms  <-- BEST (saved run17.pt)
# Epoch 038 | train 0.4101/0.9947 | val 0.5297/0.9390 | inf 11.13ms
# Epoch 039 | train 0.3957/0.9974 | val 0.5024/0.9512 | inf 10.52ms  <-- BEST (saved run17.pt)
# Epoch 040 | train 0.3909/0.9974 | val 0.5135/0.9512 | inf 9.57ms
# Epoch 041 | train 0.3915/0.9921 | val 0.5898/0.9146 | inf 18.53ms
# Epoch 042 | train 0.4068/0.9868 | val 0.5072/0.9512 | inf 9.87ms
# Epoch 043 | train 0.4033/0.9894 | val 0.5271/0.9146 | inf 4.20ms
# Epoch 044 | train 0.3879/0.9947 | val 0.5534/0.9146 | inf 4.66ms
# Epoch 045 | train 0.3831/0.9974 | val 0.4957/0.9634 | inf 4.13ms  <-- BEST (saved run17.pt)
# Epoch 046 | train 0.4034/0.9894 | val 0.5216/0.9512 | inf 9.29ms
# Epoch 047 | train 0.4111/0.9868 | val 0.5079/0.9390 | inf 10.80ms
# Epoch 048 | train 0.3892/0.9947 | val 0.5071/0.9512 | inf 11.29ms
# Epoch 049 | train 0.3939/0.9894 | val 0.4724/0.9390 | inf 10.72ms  <-- BEST (saved run17.pt)
# Epoch 050 | train 0.3808/0.9974 | val 0.5687/0.9390 | inf 14.93ms
# Epoch 051 | train 0.3735/1.0000 | val 0.4995/0.9512 | inf 10.61ms
# Epoch 052 | train 0.3983/0.9868 | val 0.4774/0.9512 | inf 10.82ms
# Epoch 053 | train 0.3894/0.9894 | val 0.5866/0.9146 | inf 9.03ms
# Epoch 054 | train 0.3852/0.9947 | val 0.5334/0.9634 | inf 10.58ms
# Epoch 055 | train 0.3684/1.0000 | val 0.4923/0.9634 | inf 10.56ms
# Epoch 056 | train 0.3740/0.9947 | val 0.5152/0.9512 | inf 9.95ms
# Epoch 057 | train 0.3717/0.9974 | val 0.4954/0.9634 | inf 10.24ms
# Epoch 058 | train 0.3659/1.0000 | val 0.4806/0.9512 | inf 10.39ms
# Early stopping (no improve 10 epochs, best@48)
#
# === [SUMMARY] ===
# Best epoch: 48, best val loss: 0.4724
# ========================

# %% [markdown]
# # Training with hyperparameter tuning

# %%
HPO_SPACE = {
    "optimizer": ["adam", "adamw"],
    "lr": [7e-4, 5e-4, 3e-4, 2e-4, 1e-4],
    "dropout": [0.40, 0.30, 0.35],
    "weight_decay": [0.0, 1e-6, 1e-5],
    "hidden_size": [212, 234, 256, 280, 300],
    "num_layers": [2],
    "label_smoothing": [0.0, 0.05],
    "scheduler": ["cosine", "plateau"],
}

def sample_candidates(space, n=20, seed=2025):
    rng = random.Random(seed)
    keys = list(space.keys())
    return [{k: rng.choice(space[k]) for k in keys} for _ in range(n)]

candidates = sample_candidates(HPO_SPACE, n=50)
print(f"Testing {len(candidates)} candidate hyperparameter sets")

def quick_eval(hparams, max_epochs=80):
    local_config = deepcopy(CONFIG)
    local_config.update({
        "LR": hparams["lr"],
        "WEIGHT_DECAY": hparams["weight_decay"],
        "DROPOUT": hparams["dropout"],
    })

    model = build_modified_lstm(
        len(local_config["CLASSES"]),
        input_size=local_config["FEATURE_DIM"],
        hidden_size=hparams["hidden_size"],
        num_layers=hparams["num_layers"],
        dropout=hparams["dropout"],
        use_layernorm=True
    )

    model = model.to(device)

    criterion = nn.CrossEntropyLoss(
        weight=class_weights.to(device),
        label_smoothing=hparams["label_smoothing"]
    )

    if hparams["optimizer"] == "adam":
        optimizer = torch.optim.Adam(
            model.parameters(),
            lr=hparams["lr"],
            weight_decay=hparams["weight_decay"]
        )
    else:
        optimizer = torch.optim.AdamW(
            model.parameters(),
            lr=hparams["lr"],
            weight_decay=hparams["weight_decay"]
        )

    if hparams["scheduler"] == "cosine":
        scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
            optimizer, T_0=5, T_mult=2, eta_min=hparams["lr"] * 0.1
        )
    else:
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer, mode="min", patience=4
        )
        
    use_cuda = torch.cuda.is_available()
    scaler = GradScaler(enabled=torch.cuda.is_available())
    best_val_loss = float("inf")
    patience = 15
    bad_epochs = 0
    start = time.time()

    for epoch in range(max_epochs):
        model.train()
        for x, lens, y, _paths in train_loader:
            x, y = x.to(device).float(), y.to(device).long()
            reset_mask = (x[..., CONFIG["FLAG_START"]:CONFIG["FLAG_END"]].sum(dim=-1) > 0).float()
            optimizer.zero_grad(set_to_none=True)
            with autocast(device_type="cuda", enabled=torch.cuda.is_available()):
                logits = model(x, reset_mask=reset_mask)
                loss = criterion(logits, y)
            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()

        model.eval()
        total_loss, total = 0.0, 0
        with torch.no_grad():
            for x, lens, y, _paths in val_loader:
                x, y = x.to(device).float(), y.to(device).long()
                reset_mask = (x[..., CONFIG["FLAG_START"]:CONFIG["FLAG_END"]].sum(dim=-1) > 0).float()
                logits = model(x, reset_mask=reset_mask)
                loss = criterion(logits, y)
                total_loss += loss.item() * y.size(0)
                total += y.size(0)
        val_loss = total_loss / max(1, total)

        if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
            scheduler.step(val_loss)
        else:
            scheduler.step(epoch)

        if val_loss < best_val_loss - 1e-4:
            best_val_loss = val_loss
            bad_epochs = 0
        else:
            bad_epochs += 1
            if bad_epochs >= patience:
                print(f"early stop @ epoch {epoch+1}")
                break

        if (epoch + 1) % 10 == 0 or epoch == 0:
            print(f"epoch {epoch+1}/{max_epochs} val_loss={val_loss:.4f}")

    elapsed = time.time() - start
    return best_val_loss, elapsed
# Out:
# Testing 50 candidate hyperparameter sets

# %% [markdown]
# The best hyperparameters found were
# Best hyperparameters found:
# {
#     "optimizer": "adamw",
#     "lr": 0.0003,
#     "dropout": 0.35,
#     "weight_decay": 1e-05,
#     "hidden_size": 384,
#     "num_layers": 2,
#     "label_smoothing": 0.0,
#     "scheduler": "plateau"
# }
# Best validation loss: 0.1485 (trained 18.9s)

# %%
hpo_start = time.time()
results = []

for i, hparams in enumerate(candidates, 1):
    print(f"\nCandidate {i}/{len(candidates)}")
    print(hparams)

    candidate_start = time.time()
    val_loss, elapsed = quick_eval(hparams, max_epochs=80)
    candidate_time = time.time() - candidate_start

    results.append((val_loss, hparams, candidate_time))

    print(f"Validation loss: {val_loss:.4f}")
    print(f"Candidate time: {candidate_time:.2f} sec")

hpo_total_time = time.time() - hpo_start

results.sort(key=lambda x: x[0])
best_loss, best_hparams, best_time = results[0]

print(json.dumps(best_hparams, indent=4))
print(f"Best validation loss: {best_loss:.4f}")
print(f"Best candidate training time: {best_time:.2f} sec")
print(f"Total HPO time: {hpo_total_time/60:.2f} minutes")
# Out:
# Candidate 1/50
# {'optimizer': 'adam', 'lr': 0.0002, 'dropout': 0.4, 'weight_decay': 1e-05, 'hidden_size': 212, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=3.1206
# epoch 10/80 val_loss=2.0921
# epoch 20/80 val_loss=1.4657
# epoch 30/80 val_loss=1.0275
# epoch 40/80 val_loss=0.8311
# epoch 50/80 val_loss=0.6052
# epoch 60/80 val_loss=0.5275
# epoch 70/80 val_loss=0.4953
# epoch 80/80 val_loss=0.4884
# Validation loss: 0.4832
# Candidate time: 113.28 sec
#
# Candidate 2/50
# {'optimizer': 'adam', 'lr': 0.0002, 'dropout': 0.3, 'weight_decay': 0.0, 'hidden_size': 212, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=3.1329
# epoch 10/80 val_loss=1.7775
# epoch 20/80 val_loss=0.9116
# epoch 30/80 val_loss=0.5053
# epoch 40/80 val_loss=0.2987
# epoch 50/80 val_loss=0.1839
# epoch 60/80 val_loss=0.1471
# epoch 70/80 val_loss=0.1228
# epoch 80/80 val_loss=0.1102
# Validation loss: 0.1058
# Candidate time: 118.93 sec
#
# Candidate 3/50
# {'optimizer': 'adam', 'lr': 0.0002, 'dropout': 0.4, 'weight_decay': 1e-05, 'hidden_size': 212, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=3.1381
# epoch 10/80 val_loss=2.0362
# epoch 20/80 val_loss=1.3599
# epoch 30/80 val_loss=0.8759
# epoch 40/80 val_loss=0.6586
# epoch 50/80 val_loss=0.4494
# epoch 60/80 val_loss=0.2693
# epoch 70/80 val_loss=0.2117
# epoch 80/80 val_loss=0.1867
# Validation loss: 0.1867
# Candidate time: 167.08 sec
#
# Candidate 4/50
# {'optimizer': 'adam', 'lr': 0.0005, 'dropout': 0.35, 'weight_decay': 1e-06, 'hidden_size': 280, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=2.8761
# epoch 10/80 val_loss=0.9032
# epoch 20/80 val_loss=0.5174
# epoch 30/80 val_loss=0.2071
# epoch 40/80 val_loss=0.2738
# epoch 50/80 val_loss=0.3109
# epoch 60/80 val_loss=0.1294
# epoch 70/80 val_loss=0.1252
# early stop @ epoch 79
# Validation loss: 0.1113
# Candidate time: 239.89 sec
#
# Candidate 5/50
# {'optimizer': 'adam', 'lr': 0.0005, 'dropout': 0.4, 'weight_decay': 0.0, 'hidden_size': 300, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=2.8481
# epoch 10/80 val_loss=0.9136
# epoch 20/80 val_loss=0.5617
# epoch 30/80 val_loss=0.1844
# epoch 40/80 val_loss=0.5167
# early stop @ epoch 49
# Validation loss: 0.1628
# Candidate time: 138.47 sec
#
# Candidate 6/50
# {'optimizer': 'adamw', 'lr': 0.0007, 'dropout': 0.35, 'weight_decay': 1e-06, 'hidden_size': 256, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=2.8524
# epoch 10/80 val_loss=0.9007
# epoch 20/80 val_loss=0.4388
# epoch 30/80 val_loss=0.3583
# epoch 40/80 val_loss=0.1359
# epoch 50/80 val_loss=0.1375
# early stop @ epoch 55
# Validation loss: 0.1359
# Candidate time: 154.20 sec
#
# Candidate 7/50
# {'optimizer': 'adamw', 'lr': 0.0001, 'dropout': 0.3, 'weight_decay': 1e-06, 'hidden_size': 212, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=3.1964
# epoch 10/80 val_loss=2.3821
# epoch 20/80 val_loss=1.6406
# epoch 30/80 val_loss=1.1564
# epoch 40/80 val_loss=0.8146
# epoch 50/80 val_loss=0.5839
# epoch 60/80 val_loss=0.4112
# epoch 70/80 val_loss=0.2756
# epoch 80/80 val_loss=0.2055
# Validation loss: 0.2055
# Candidate time: 230.31 sec
#
# Candidate 8/50
# {'optimizer': 'adam', 'lr': 0.0003, 'dropout': 0.4, 'weight_decay': 1e-05, 'hidden_size': 300, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=3.0043
# epoch 10/80 val_loss=1.0657
# epoch 20/80 val_loss=0.4546
# epoch 30/80 val_loss=0.3206
# epoch 40/80 val_loss=0.1534
# epoch 50/80 val_loss=0.1542
# early stop @ epoch 54
# Validation loss: 0.1309
# Candidate time: 153.68 sec
#
# Candidate 9/50
# {'optimizer': 'adamw', 'lr': 0.0003, 'dropout': 0.3, 'weight_decay': 0.0, 'hidden_size': 300, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=2.9709
# epoch 10/80 val_loss=1.1351
# epoch 20/80 val_loss=0.7800
# epoch 30/80 val_loss=0.5773
# epoch 40/80 val_loss=0.5164
# epoch 50/80 val_loss=0.5046
# epoch 60/80 val_loss=0.5084
# early stop @ epoch 62
# Validation loss: 0.5024
# Candidate time: 185.45 sec
#
# Candidate 10/50
# {'optimizer': 'adam', 'lr': 0.0007, 'dropout': 0.3, 'weight_decay': 1e-05, 'hidden_size': 300, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=2.9255
# epoch 10/80 val_loss=0.8856
# epoch 20/80 val_loss=0.6321
# epoch 30/80 val_loss=0.6880
# epoch 40/80 val_loss=0.5050
# epoch 50/80 val_loss=0.5016
# early stop @ epoch 51
# Validation loss: 0.4951
# Candidate time: 142.44 sec
#
# Candidate 11/50
# {'optimizer': 'adam', 'lr': 0.0003, 'dropout': 0.35, 'weight_decay': 0.0, 'hidden_size': 300, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=2.9631
# epoch 10/80 val_loss=1.2470
# epoch 20/80 val_loss=0.6466
# epoch 30/80 val_loss=0.3108
# epoch 40/80 val_loss=0.2132
# epoch 50/80 val_loss=0.2610
# epoch 60/80 val_loss=0.1623
# epoch 70/80 val_loss=0.1501
# early stop @ epoch 77
# Validation loss: 0.1459
# Candidate time: 204.95 sec
#
# Candidate 12/50
# {'optimizer': 'adam', 'lr': 0.0005, 'dropout': 0.4, 'weight_decay': 0.0, 'hidden_size': 280, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=2.9917
# epoch 10/80 val_loss=1.1591
# epoch 20/80 val_loss=0.8192
# epoch 30/80 val_loss=0.5651
# epoch 40/80 val_loss=0.5726
# epoch 50/80 val_loss=0.6468
# epoch 60/80 val_loss=0.4945
# epoch 70/80 val_loss=0.4589
# early stop @ epoch 74
# Validation loss: 0.4527
# Candidate time: 200.13 sec
#
# Candidate 13/50
# {'optimizer': 'adam', 'lr': 0.0001, 'dropout': 0.3, 'weight_decay': 0.0, 'hidden_size': 234, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=3.2004
# epoch 10/80 val_loss=2.2543
# epoch 20/80 val_loss=1.5021
# epoch 30/80 val_loss=1.0358
# epoch 40/80 val_loss=0.7169
# epoch 50/80 val_loss=0.4727
# epoch 60/80 val_loss=0.3176
# epoch 70/80 val_loss=0.2224
# epoch 80/80 val_loss=0.1761
# Validation loss: 0.1699
# Candidate time: 212.46 sec
#
# Candidate 14/50
# {'optimizer': 'adamw', 'lr': 0.0005, 'dropout': 0.35, 'weight_decay': 1e-05, 'hidden_size': 256, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=2.9381
# epoch 10/80 val_loss=0.8536
# epoch 20/80 val_loss=0.3820
# epoch 30/80 val_loss=0.3676
# epoch 40/80 val_loss=0.4629
# epoch 50/80 val_loss=0.1257
# epoch 60/80 val_loss=0.1271
# early stop @ epoch 64
# Validation loss: 0.1202
# Candidate time: 167.17 sec
#
# Candidate 15/50
# {'optimizer': 'adam', 'lr': 0.0001, 'dropout': 0.3, 'weight_decay': 0.0, 'hidden_size': 212, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=3.1921
# epoch 10/80 val_loss=2.3530
# epoch 20/80 val_loss=1.6374
# epoch 30/80 val_loss=1.1534
# epoch 40/80 val_loss=0.7790
# epoch 50/80 val_loss=0.5320
# epoch 60/80 val_loss=0.3563
# epoch 70/80 val_loss=0.2553
# epoch 80/80 val_loss=0.1938
# Validation loss: 0.1938
# Candidate time: 212.84 sec
#
# Candidate 16/50
# {'optimizer': 'adamw', 'lr': 0.0001, 'dropout': 0.35, 'weight_decay': 0.0, 'hidden_size': 212, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=3.1860
# epoch 10/80 val_loss=2.4256
# epoch 20/80 val_loss=1.7470
# epoch 30/80 val_loss=1.3267
# epoch 40/80 val_loss=1.0197
# epoch 50/80 val_loss=0.8191
# epoch 60/80 val_loss=0.6478
# epoch 70/80 val_loss=0.5790
# epoch 80/80 val_loss=0.5281
# Validation loss: 0.5163
# Candidate time: 223.92 sec
#
# Candidate 17/50
# {'optimizer': 'adamw', 'lr': 0.0003, 'dropout': 0.3, 'weight_decay': 0.0, 'hidden_size': 234, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=3.0618
# epoch 10/80 val_loss=1.4108
# epoch 20/80 val_loss=0.8047
# epoch 30/80 val_loss=0.6209
# epoch 40/80 val_loss=0.5334
# epoch 50/80 val_loss=0.5144
# epoch 60/80 val_loss=0.5140
# early stop @ epoch 67
# Validation loss: 0.4956
# Candidate time: 185.97 sec
#
# Candidate 18/50
# {'optimizer': 'adamw', 'lr': 0.0003, 'dropout': 0.3, 'weight_decay': 0.0, 'hidden_size': 234, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=3.0858
# epoch 10/80 val_loss=1.6959
# epoch 20/80 val_loss=1.0513
# epoch 30/80 val_loss=0.7062
# epoch 40/80 val_loss=0.6033
# epoch 50/80 val_loss=0.5859
# epoch 60/80 val_loss=0.4879
# epoch 70/80 val_loss=0.4982
# early stop @ epoch 73
# Validation loss: 0.4602
# Candidate time: 202.06 sec
#
# Candidate 19/50
# {'optimizer': 'adamw', 'lr': 0.0005, 'dropout': 0.35, 'weight_decay': 0.0, 'hidden_size': 280, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=2.9353
# epoch 10/80 val_loss=0.9895
# epoch 20/80 val_loss=0.6648
# epoch 30/80 val_loss=0.1869
# epoch 40/80 val_loss=0.2535
# epoch 50/80 val_loss=0.1829
# early stop @ epoch 51
# Validation loss: 0.1785
# Candidate time: 132.17 sec
#
# Candidate 20/50
# {'optimizer': 'adam', 'lr': 0.0003, 'dropout': 0.3, 'weight_decay': 1e-05, 'hidden_size': 212, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=3.0872
# epoch 10/80 val_loss=1.3755
# epoch 20/80 val_loss=0.6441
# epoch 30/80 val_loss=0.4056
# epoch 40/80 val_loss=0.2490
# epoch 50/80 val_loss=0.1203
# epoch 60/80 val_loss=0.1184
# epoch 70/80 val_loss=0.1150
# early stop @ epoch 72
# Validation loss: 0.1138
# Candidate time: 192.92 sec
#
# Candidate 21/50
# {'optimizer': 'adamw', 'lr': 0.0005, 'dropout': 0.35, 'weight_decay': 1e-06, 'hidden_size': 300, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=2.8449
# epoch 10/80 val_loss=0.8135
# epoch 20/80 val_loss=0.7520
# epoch 30/80 val_loss=0.1546
# epoch 40/80 val_loss=0.2618
# early stop @ epoch 47
# Validation loss: 0.1370
# Candidate time: 125.68 sec
#
# Candidate 22/50
# {'optimizer': 'adamw', 'lr': 0.0001, 'dropout': 0.35, 'weight_decay': 1e-06, 'hidden_size': 256, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=3.2064
# epoch 10/80 val_loss=2.4123
# epoch 20/80 val_loss=1.8891
# epoch 30/80 val_loss=1.4635
# epoch 40/80 val_loss=1.2361
# epoch 50/80 val_loss=0.9186
# epoch 60/80 val_loss=0.7529
# epoch 70/80 val_loss=0.6869
# epoch 80/80 val_loss=0.6216
# Validation loss: 0.6216
# Candidate time: 218.49 sec
#
# Candidate 23/50
# {'optimizer': 'adamw', 'lr': 0.0002, 'dropout': 0.35, 'weight_decay': 1e-05, 'hidden_size': 212, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=3.1311
# epoch 10/80 val_loss=1.7703
# epoch 20/80 val_loss=0.9259
# epoch 30/80 val_loss=0.4635
# epoch 40/80 val_loss=0.2407
# epoch 50/80 val_loss=0.2068
# epoch 60/80 val_loss=0.1276
# epoch 70/80 val_loss=0.1256
# early stop @ epoch 80
# Validation loss: 0.1203
# Candidate time: 212.76 sec
#
# Candidate 24/50
# {'optimizer': 'adam', 'lr': 0.0007, 'dropout': 0.35, 'weight_decay': 1e-06, 'hidden_size': 280, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=2.8447
# epoch 10/80 val_loss=0.9773
# epoch 20/80 val_loss=0.8226
# epoch 30/80 val_loss=0.5140
# epoch 40/80 val_loss=0.6353
# early stop @ epoch 44
# Validation loss: 0.5056
# Candidate time: 118.86 sec
#
# Candidate 25/50
# {'optimizer': 'adam', 'lr': 0.0003, 'dropout': 0.4, 'weight_decay': 0.0, 'hidden_size': 300, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=3.0243
# epoch 10/80 val_loss=1.1588
# epoch 20/80 val_loss=0.6601
# epoch 30/80 val_loss=0.5522
# epoch 40/80 val_loss=0.5275
# epoch 50/80 val_loss=0.5070
# epoch 60/80 val_loss=0.5110
# early stop @ epoch 65
# Validation loss: 0.5070
# Candidate time: 180.64 sec
#
# Candidate 26/50
# {'optimizer': 'adam', 'lr': 0.0003, 'dropout': 0.4, 'weight_decay': 1e-06, 'hidden_size': 256, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=3.0114
# epoch 10/80 val_loss=1.1982
# epoch 20/80 val_loss=0.5335
# epoch 30/80 val_loss=0.2797
# epoch 40/80 val_loss=0.2030
# epoch 50/80 val_loss=0.1575
# early stop @ epoch 58
# Validation loss: 0.1365
# Candidate time: 126.75 sec
#
# Candidate 27/50
# {'optimizer': 'adamw', 'lr': 0.0007, 'dropout': 0.3, 'weight_decay': 1e-06, 'hidden_size': 256, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=2.9579
# epoch 10/80 val_loss=1.0639
# epoch 20/80 val_loss=0.7243
# epoch 30/80 val_loss=0.5153
# epoch 40/80 val_loss=0.6927
# early stop @ epoch 50
# Validation loss: 0.5040
# Candidate time: 94.87 sec
#
# Candidate 28/50
# {'optimizer': 'adamw', 'lr': 0.0003, 'dropout': 0.35, 'weight_decay': 1e-06, 'hidden_size': 212, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=3.0274
# epoch 10/80 val_loss=1.3315
# epoch 20/80 val_loss=0.6087
# epoch 30/80 val_loss=0.3835
# epoch 40/80 val_loss=0.2633
# epoch 50/80 val_loss=0.1982
# early stop @ epoch 56
# Validation loss: 0.1833
# Candidate time: 139.80 sec
#
# Candidate 29/50
# {'optimizer': 'adamw', 'lr': 0.0002, 'dropout': 0.4, 'weight_decay': 0.0, 'hidden_size': 256, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=3.0931
# epoch 10/80 val_loss=1.8742
# epoch 20/80 val_loss=1.2667
# epoch 30/80 val_loss=0.8651
# epoch 40/80 val_loss=0.8047
# epoch 50/80 val_loss=0.5573
# epoch 60/80 val_loss=0.4612
# epoch 70/80 val_loss=0.4588
# epoch 80/80 val_loss=0.4865
# Validation loss: 0.4453
# Candidate time: 247.34 sec
#
# Candidate 30/50
# {'optimizer': 'adam', 'lr': 0.0005, 'dropout': 0.35, 'weight_decay': 0.0, 'hidden_size': 256, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=2.9711
# epoch 10/80 val_loss=0.9882
# epoch 20/80 val_loss=0.7895
# epoch 30/80 val_loss=0.5383
# epoch 40/80 val_loss=0.5190
# epoch 50/80 val_loss=0.5133
# epoch 60/80 val_loss=0.5170
# early stop @ epoch 62
# Validation loss: 0.5109
# Candidate time: 170.53 sec
#
# Candidate 31/50
# {'optimizer': 'adamw', 'lr': 0.0005, 'dropout': 0.4, 'weight_decay': 0.0, 'hidden_size': 300, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=2.9627
# epoch 10/80 val_loss=1.0094
# epoch 20/80 val_loss=0.6289
# epoch 30/80 val_loss=0.5502
# epoch 40/80 val_loss=0.5439
# epoch 50/80 val_loss=0.5103
# epoch 60/80 val_loss=0.5099
# epoch 70/80 val_loss=0.4910
# epoch 80/80 val_loss=0.4965
# Validation loss: 0.4858
# Candidate time: 239.44 sec
#
# Candidate 32/50
# {'optimizer': 'adam', 'lr': 0.0007, 'dropout': 0.35, 'weight_decay': 1e-06, 'hidden_size': 256, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=2.9011
# epoch 10/80 val_loss=0.7068
# epoch 20/80 val_loss=0.5033
# epoch 30/80 val_loss=0.2105
# epoch 40/80 val_loss=0.1782
# epoch 50/80 val_loss=0.1658
# epoch 60/80 val_loss=0.1626
# epoch 70/80 val_loss=0.1624
# early stop @ epoch 79
# Validation loss: 0.1611
# Candidate time: 209.42 sec
#
# Candidate 33/50
# {'optimizer': 'adam', 'lr': 0.0002, 'dropout': 0.35, 'weight_decay': 1e-05, 'hidden_size': 234, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=3.1215
# epoch 10/80 val_loss=1.8547
# epoch 20/80 val_loss=1.1785
# epoch 30/80 val_loss=0.7133
# epoch 40/80 val_loss=0.5363
# epoch 50/80 val_loss=0.3511
# epoch 60/80 val_loss=0.2117
# epoch 70/80 val_loss=0.1769
# epoch 80/80 val_loss=0.1997
# Validation loss: 0.1679
# Candidate time: 207.22 sec
#
# Candidate 34/50
# {'optimizer': 'adamw', 'lr': 0.0002, 'dropout': 0.3, 'weight_decay': 1e-06, 'hidden_size': 212, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=3.1358
# epoch 10/80 val_loss=2.1535
# epoch 20/80 val_loss=1.5265
# epoch 30/80 val_loss=1.0557
# epoch 40/80 val_loss=0.8772
# epoch 50/80 val_loss=0.6318
# epoch 60/80 val_loss=0.5277
# epoch 70/80 val_loss=0.5171
# epoch 80/80 val_loss=0.5367
# Validation loss: 0.5072
# Candidate time: 216.73 sec
#
# Candidate 35/50
# {'optimizer': 'adam', 'lr': 0.0005, 'dropout': 0.3, 'weight_decay': 0.0, 'hidden_size': 256, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=2.9296
# epoch 10/80 val_loss=1.0394
# epoch 20/80 val_loss=0.5845
# epoch 30/80 val_loss=0.2392
# epoch 40/80 val_loss=0.3858
# epoch 50/80 val_loss=0.3839
# early stop @ epoch 51
# Validation loss: 0.1711
# Candidate time: 129.71 sec
#
# Candidate 36/50
# {'optimizer': 'adam', 'lr': 0.0005, 'dropout': 0.35, 'weight_decay': 0.0, 'hidden_size': 234, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=2.9856
# epoch 10/80 val_loss=0.8896
# epoch 20/80 val_loss=0.3953
# epoch 30/80 val_loss=0.5257
# epoch 40/80 val_loss=0.1434
# epoch 50/80 val_loss=0.1230
# epoch 60/80 val_loss=0.1303
# early stop @ epoch 65
# Validation loss: 0.1230
# Candidate time: 118.76 sec
#
# Candidate 37/50
# {'optimizer': 'adam', 'lr': 0.0007, 'dropout': 0.35, 'weight_decay': 0.0, 'hidden_size': 234, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=2.9084
# epoch 10/80 val_loss=0.8675
# epoch 20/80 val_loss=0.4618
# epoch 30/80 val_loss=0.2008
# epoch 40/80 val_loss=0.2593
# epoch 50/80 val_loss=0.2477
# early stop @ epoch 51
# Validation loss: 0.1778
# Candidate time: 95.90 sec
#
# Candidate 38/50
# {'optimizer': 'adamw', 'lr': 0.0005, 'dropout': 0.35, 'weight_decay': 1e-06, 'hidden_size': 234, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=3.0400
# epoch 10/80 val_loss=1.1065
# epoch 20/80 val_loss=0.7906
# epoch 30/80 val_loss=0.6804
# epoch 40/80 val_loss=0.5986
# epoch 50/80 val_loss=0.4877
# epoch 60/80 val_loss=0.4901
# early stop @ epoch 64
# Validation loss: 0.4864
# Candidate time: 180.98 sec
#
# Candidate 39/50
# {'optimizer': 'adam', 'lr': 0.0005, 'dropout': 0.3, 'weight_decay': 1e-05, 'hidden_size': 234, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=2.9615
# epoch 10/80 val_loss=1.2636
# epoch 20/80 val_loss=0.8267
# epoch 30/80 val_loss=0.5627
# epoch 40/80 val_loss=0.7019
# early stop @ epoch 46
# Validation loss: 0.5137
# Candidate time: 98.06 sec
#
# Candidate 40/50
# {'optimizer': 'adamw', 'lr': 0.0003, 'dropout': 0.35, 'weight_decay': 0.0, 'hidden_size': 300, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=3.0130
# epoch 10/80 val_loss=1.1778
# epoch 20/80 val_loss=0.6785
# epoch 30/80 val_loss=0.7126
# epoch 40/80 val_loss=0.4809
# epoch 50/80 val_loss=0.4823
# early stop @ epoch 57
# Validation loss: 0.4759
# Candidate time: 108.52 sec
#
# Candidate 41/50
# {'optimizer': 'adam', 'lr': 0.0005, 'dropout': 0.35, 'weight_decay': 0.0, 'hidden_size': 212, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=2.9793
# epoch 10/80 val_loss=0.9134
# epoch 20/80 val_loss=0.3458
# epoch 30/80 val_loss=0.6403
# epoch 40/80 val_loss=0.2530
# epoch 50/80 val_loss=0.1383
# epoch 60/80 val_loss=0.1431
# early stop @ epoch 66
# Validation loss: 0.1375
# Candidate time: 126.84 sec
#
# Candidate 42/50
# {'optimizer': 'adamw', 'lr': 0.0005, 'dropout': 0.35, 'weight_decay': 1e-05, 'hidden_size': 300, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=2.9441
# epoch 10/80 val_loss=0.9461
# epoch 20/80 val_loss=0.6430
# epoch 30/80 val_loss=0.5024
# epoch 40/80 val_loss=0.5036
# early stop @ epoch 46
# Validation loss: 0.4958
# Candidate time: 92.72 sec
#
# Candidate 43/50
# {'optimizer': 'adamw', 'lr': 0.0001, 'dropout': 0.35, 'weight_decay': 0.0, 'hidden_size': 280, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=3.1959
# epoch 10/80 val_loss=2.3845
# epoch 20/80 val_loss=1.8030
# epoch 30/80 val_loss=1.3799
# epoch 40/80 val_loss=1.1751
# epoch 50/80 val_loss=0.8670
# epoch 60/80 val_loss=0.7294
# epoch 70/80 val_loss=0.6580
# epoch 80/80 val_loss=0.6242
# Validation loss: 0.6149
# Candidate time: 141.23 sec
#
# Candidate 44/50
# {'optimizer': 'adam', 'lr': 0.0003, 'dropout': 0.4, 'weight_decay': 0.0, 'hidden_size': 300, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=3.0243
# epoch 10/80 val_loss=1.2679
# epoch 20/80 val_loss=0.6768
# epoch 30/80 val_loss=0.3134
# epoch 40/80 val_loss=0.2794
# epoch 50/80 val_loss=0.2220
# epoch 60/80 val_loss=0.1598
# epoch 70/80 val_loss=0.1426
# early stop @ epoch 72
# Validation loss: 0.1367
# Candidate time: 144.72 sec
#
# Candidate 45/50
# {'optimizer': 'adam', 'lr': 0.0003, 'dropout': 0.4, 'weight_decay': 1e-05, 'hidden_size': 256, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=3.0519
# epoch 10/80 val_loss=1.6094
# epoch 20/80 val_loss=1.0493
# epoch 30/80 val_loss=0.6817
# epoch 40/80 val_loss=0.6051
# epoch 50/80 val_loss=0.5291
# epoch 60/80 val_loss=0.4694
# epoch 70/80 val_loss=0.5014
# early stop @ epoch 71
# Validation loss: 0.4677
# Candidate time: 145.75 sec
#
# Candidate 46/50
# {'optimizer': 'adam', 'lr': 0.0002, 'dropout': 0.35, 'weight_decay': 0.0, 'hidden_size': 300, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=3.0507
# epoch 10/80 val_loss=1.4408
# epoch 20/80 val_loss=0.6250
# epoch 30/80 val_loss=0.3560
# epoch 40/80 val_loss=0.1713
# epoch 50/80 val_loss=0.1553
# early stop @ epoch 59
# Validation loss: 0.1422
# Candidate time: 118.27 sec
#
# Candidate 47/50
# {'optimizer': 'adam', 'lr': 0.0001, 'dropout': 0.35, 'weight_decay': 1e-05, 'hidden_size': 256, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=3.2135
# epoch 10/80 val_loss=2.4738
# epoch 20/80 val_loss=1.9152
# epoch 30/80 val_loss=1.4762
# epoch 40/80 val_loss=1.2388
# epoch 50/80 val_loss=0.9358
# epoch 60/80 val_loss=0.7891
# epoch 70/80 val_loss=0.7009
# epoch 80/80 val_loss=0.6396
# Validation loss: 0.6396
# Candidate time: 155.48 sec
#
# Candidate 48/50
# {'optimizer': 'adam', 'lr': 0.0007, 'dropout': 0.3, 'weight_decay': 1e-05, 'hidden_size': 234, 'num_layers': 2, 'label_smoothing': 0.05, 'scheduler': 'cosine'}
# epoch 1/80 val_loss=2.9635
# epoch 10/80 val_loss=1.1910
# epoch 20/80 val_loss=0.8315
# epoch 30/80 val_loss=0.5251
# epoch 40/80 val_loss=0.7776
# early stop @ epoch 45
# Validation loss: 0.5251
# Candidate time: 102.50 sec
#
# Candidate 49/50
# {'optimizer': 'adam', 'lr': 0.0005, 'dropout': 0.3, 'weight_decay': 0.0, 'hidden_size': 300, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=2.8763
# epoch 10/80 val_loss=0.6674
# epoch 20/80 val_loss=0.3625
# epoch 30/80 val_loss=0.1597
# epoch 40/80 val_loss=0.1608
# epoch 50/80 val_loss=0.1493
# early stop @ epoch 59
# Validation loss: 0.1389
# Candidate time: 118.38 sec
#
# Candidate 50/50
# {'optimizer': 'adamw', 'lr': 0.0007, 'dropout': 0.3, 'weight_decay': 0.0, 'hidden_size': 234, 'num_layers': 2, 'label_smoothing': 0.0, 'scheduler': 'plateau'}
# epoch 1/80 val_loss=2.9051
# epoch 10/80 val_loss=0.7388
# epoch 20/80 val_loss=0.6789
# epoch 30/80 val_loss=0.2075
# epoch 40/80 val_loss=0.1911
# early stop @ epoch 48
# Validation loss: 0.1818
# Candidate time: 90.55 sec
# {
#     "optimizer": "adam",
#     "lr": 0.0002,
#     "dropout": 0.3,
#     "weight_decay": 0.0,
#     "hidden_size": 212,
#     "num_layers": 2,
#     "label_smoothing": 0.0,
#     "scheduler": "plateau"
# }
# Best validation loss: 0.1058
# Best candidate training time: 118.93 sec
# Total HPO time: 134.25 minutes

# %%
FLAG_START = CONFIG["FLAG_START"]
FLAG_END   = CONFIG["FLAG_END"]

def train_run(best_hparams, TRAIN_FROM_SCRATCH=True, prefix="run"):
    best_dir = Path(CONFIG["BEST_DIR"])
    best_dir.mkdir(parents=True, exist_ok=True)

    run_id = _next_run_id(best_dir, prefix=prefix) if TRAIN_FROM_SCRATCH \
             else _latest_run_id(best_dir, prefix=prefix) or 1

    ckpt_name = f"{prefix}{run_id}.pt"
    weights_name = f"{prefix}{run_id}.pth"
    ckpt_path = best_dir / ckpt_name
    weights_path = best_dir / weights_name

    export_dir = Path(CONFIG["EXPORT_DIR"]) / f"{prefix}{run_id}"
    export_dir.mkdir(parents=True, exist_ok=True)

    # Apply best hyperparameters from HPO into CONFIG
    CONFIG.update({
        "LR": best_hparams["lr"],
        "DROPOUT": best_hparams["dropout"],
        "WEIGHT_DECAY": best_hparams["weight_decay"],
        "HIDDEN_SIZE": best_hparams["hidden_size"],
        "NUM_LAYERS": best_hparams["num_layers"],
        "LABEL_SMOOTHING": best_hparams["label_smoothing"],
        "OPTIMIZER": best_hparams["optimizer"],
        "SCHEDULER": best_hparams["scheduler"],
        "EPOCHS": 120,
        "PATIENCE": 20,
    })

    # Build model from CONFIG (no hardcoded sizes)
    _model = build_modified_lstm(
        len(CONFIG["CLASSES"]),
        input_size=CONFIG["FEATURE_DIM"],
        hidden_size=CONFIG["HIDDEN_SIZE"],
        num_layers=CONFIG["NUM_LAYERS"],
        dropout=CONFIG["DROPOUT"],
        use_layernorm=True
    ).to(device)

    print(f"\nTraining run {prefix}{run_id}")
    print(f"  Saving to: {best_dir}")
    print(json.dumps(best_hparams, indent=4))

    # Loss
    criterion = nn.CrossEntropyLoss(
        weight=class_weights.to(device),
        label_smoothing=CONFIG["LABEL_SMOOTHING"]
    )

    # Optimizer
    if CONFIG["OPTIMIZER"] == "adam":
        optimizer = torch.optim.Adam(
            _model.parameters(),
            lr=CONFIG["LR"],
            weight_decay=CONFIG["WEIGHT_DECAY"]
        )
    else:
        optimizer = torch.optim.AdamW(
            _model.parameters(),
            lr=CONFIG["LR"],
            weight_decay=CONFIG["WEIGHT_DECAY"]
        )

    # Scheduler
    if CONFIG["SCHEDULER"] == "cosine":
        scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
            optimizer,
            T_0=5,
            T_mult=2,
            eta_min=CONFIG["LR"] * 0.1
        )
    elif CONFIG["SCHEDULER"] == "plateau":
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer,
            mode="min",
            patience=5,
            factor=0.5
        )
    else:
        scheduler = None

    use_cuda = torch.cuda.is_available()
    scaler = GradScaler(enabled=use_cuda)

    history = defaultdict(list)
    best_val_loss = float("inf")
    best_epoch = -1
    no_improve = 0

    print("\nTraining started")
    t0 = time.time()

    for epoch in range(CONFIG["EPOCHS"]):

        epoch_start = time.time()
        # ---- TRAIN ----
        _model.train()
        total_loss, total, correct = 0, 0, 0

        for x, lens, y, _paths in train_loader:
            x = x.to(device).float()
            y = y.to(device).long()

            reset_mask = (x[..., CONFIG["FLAG_START"]:CONFIG["FLAG_END"]]
                          .sum(dim=-1) > 0).float()

            optimizer.zero_grad(set_to_none=True)

            with autocast(device_type="cuda", enabled=use_cuda):
                logits = _model(x, reset_mask=reset_mask)
                loss = criterion(logits, y)

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(_model.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()

            pred = logits.argmax(1)
            correct += (pred == y).sum().item()
            total += y.size(0)
            total_loss += loss.item() * y.size(0)

        tr_loss = total_loss / total
        tr_acc = correct / total

        # ---- VALIDATION ----
        _model.eval()
        total_loss, total, correct = 0, 0, 0

        with torch.no_grad():
            for x, lens, y, _paths in val_loader:
                x = x.to(device).float()
                y = y.to(device).long()

                reset_mask = (x[..., CONFIG["FLAG_START"]:CONFIG["FLAG_END"]]
                              .sum(dim=-1) > 0).float()

                logits = _model(x, reset_mask=reset_mask)
                loss = criterion(logits, y)

                pred = logits.argmax(1)
                correct += (pred == y).sum().item()
                total += y.size(0)
                total_loss += loss.item() * y.size(0)

        va_loss = total_loss / total
        va_acc = correct / total

        # ---- Scheduler step ----
        if scheduler is not None:
            if CONFIG["SCHEDULER"] == "plateau":
                scheduler.step(va_loss)
            else:
                scheduler.step(epoch)

        history["train_loss"].append(tr_loss)
        history["val_loss"].append(va_loss)
        history["train_acc"].append(tr_acc)
        history["val_acc"].append(va_acc)

        tag = ""
        if va_loss < best_val_loss - 1e-4:
            best_val_loss = va_loss
            best_epoch = epoch
            no_improve = 0

            torch.save(_model.state_dict(), weights_path)
            torch.save({
                "epoch": epoch,
                "model_state_dict": _model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "config": CONFIG,
                "best_val_loss": float(best_val_loss),
                "history": history,
            }, ckpt_path)

            tag = " <-- best saved"
        else:
            no_improve += 1
            if no_improve >= CONFIG["PATIENCE"]:
                print(f"Early stopping at epoch {epoch+1}")
                break
        
        epoch_time = time.time() - epoch_start
        print(f"Epoch {epoch+1:03d} | "
            f"train {tr_loss:.4f}/{tr_acc:.4f} | "
            f"val {va_loss:.4f}/{va_acc:.4f} | "
            f"{epoch_time:.2f}s{tag}")

    total_time = time.time() - t0
    avg_epoch_time = total_time / max(1, (epoch+1))

    last5 = history["val_acc"][-5:] if len(history["val_acc"]) >= 5 else history["val_acc"]
    last5_avg = sum(last5) / len(last5)

    model_size_mb = os.path.getsize(weights_path) / (1024 * 1024)

    print(f"Best epoch: {best_epoch}")
    print(f"Best val loss: {best_val_loss:.4f}")
    print(f"Last-5 Val Acc Avg: {last5_avg:.4f}")
    print(f"Total training time: {total_time/60:.2f} minutes")
    print(f"Average epoch time: {avg_epoch_time:.2f} sec")
    print(f"Model size: {model_size_mb:.2f} MB")

best_loss, best_hparams, _ = results[0]
train_run(best_hparams, TRAIN_FROM_SCRATCH=True)
# Out:
# Training run run18
# {
#     "optimizer": "adam",
#     "lr": 0.0002,
#     "dropout": 0.3,
#     "weight_decay": 0.0,
#     "hidden_size": 212,
#     "num_layers": 2,
#     "label_smoothing": 0.0,
#     "scheduler": "plateau"
# }
#
# Training started
# Epoch 001 | train 3.2483/0.0529 | val 3.1381/0.1707 | 1.84s <-- best saved
# Epoch 002 | train 3.0636/0.2381 | val 2.9636/0.3293 | 2.00s <-- best saved
# Epoch 003 | train 2.8963/0.3413 | val 2.7924/0.3537 | 1.95s <-- best saved
# Epoch 004 | train 2.7282/0.4630 | val 2.6223/0.4146 | 2.09s <-- best saved
# Epoch 005 | train 2.5578/0.5317 | val 2.4625/0.5854 | 2.50s <-- best saved
# Epoch 006 | train 2.3939/0.6005 | val 2.2948/0.6220 | 2.46s <-- best saved
# Epoch 007 | train 2.2351/0.6720 | val 2.1502/0.6098 | 2.16s <-- best saved
# Epoch 008 | train 2.0852/0.7407 | val 2.0145/0.6341 | 2.14s <-- best saved
# Epoch 009 | train 1.9441/0.7698 | val 1.8978/0.6951 | 2.07s <-- best saved
# Epoch 010 | train 1.8138/0.7751 | val 1.7555/0.7439 | 2.22s <-- best saved
# Epoch 011 | train 1.6951/0.8122 | val 1.6522/0.7317 | 1.99s <-- best saved
# Epoch 012 | train 1.5781/0.8254 | val 1.5371/0.7561 | 1.98s <-- best saved
# Epoch 013 | train 1.4751/0.8439 | val 1.4305/0.8049 | 2.25s <-- best saved
# Epoch 014 | train 1.3601/0.8995 | val 1.3364/0.8415 | 2.33s <-- best saved
# Epoch 015 | train 1.2834/0.8915 | val 1.2626/0.8415 | 2.33s <-- best saved
# Epoch 016 | train 1.1892/0.9074 | val 1.1780/0.8293 | 2.44s <-- best saved
# Epoch 017 | train 1.1098/0.9444 | val 1.1087/0.8293 | 2.51s <-- best saved
# Epoch 018 | train 1.0236/0.9206 | val 1.0333/0.8537 | 2.60s <-- best saved
# Epoch 019 | train 0.9750/0.9101 | val 0.9884/0.8537 | 2.44s <-- best saved
# Epoch 020 | train 0.8917/0.9577 | val 0.9006/0.8902 | 2.50s <-- best saved
# Epoch 021 | train 0.8231/0.9577 | val 0.8487/0.9024 | 2.04s <-- best saved
# Epoch 022 | train 0.7677/0.9577 | val 0.7882/0.9024 | 1.84s <-- best saved
# Epoch 023 | train 0.6940/0.9735 | val 0.7251/0.9390 | 1.92s <-- best saved
# Epoch 024 | train 0.6503/0.9603 | val 0.6920/0.9024 | 1.86s <-- best saved
# Epoch 025 | train 0.5891/0.9841 | val 0.6385/0.9512 | 1.86s <-- best saved
# Epoch 026 | train 0.5618/0.9709 | val 0.6224/0.9268 | 1.72s <-- best saved
# Epoch 027 | train 0.5169/0.9815 | val 0.5955/0.9146 | 1.66s <-- best saved
# Epoch 028 | train 0.4781/0.9868 | val 0.5618/0.9024 | 1.79s <-- best saved
# Epoch 029 | train 0.4377/0.9841 | val 0.5043/0.9146 | 2.18s <-- best saved
# Epoch 030 | train 0.3921/0.9894 | val 0.4957/0.9146 | 2.56s <-- best saved
# Epoch 031 | train 0.3756/0.9788 | val 0.4487/0.9390 | 2.27s <-- best saved
# Epoch 032 | train 0.3373/0.9868 | val 0.4210/0.9390 | 2.28s <-- best saved
# Epoch 033 | train 0.3052/0.9868 | val 0.4709/0.9146 | 2.17s
# Epoch 034 | train 0.2887/0.9921 | val 0.3669/0.9512 | 2.20s <-- best saved
# Epoch 035 | train 0.2713/0.9815 | val 0.3597/0.9146 | 2.39s <-- best saved
# Epoch 036 | train 0.2376/0.9921 | val 0.3256/0.9390 | 2.31s <-- best saved
# Epoch 037 | train 0.2351/0.9868 | val 0.2977/0.9512 | 2.15s <-- best saved
# Epoch 038 | train 0.1984/0.9894 | val 0.2979/0.9390 | 1.99s
# Epoch 039 | train 0.1799/0.9947 | val 0.3286/0.9024 | 1.92s
# Epoch 040 | train 0.1775/0.9947 | val 0.2577/0.9634 | 2.14s <-- best saved
# Epoch 041 | train 0.1699/0.9894 | val 0.2933/0.9268 | 1.41s
# Epoch 042 | train 0.1476/0.9921 | val 0.2582/0.9634 | 1.24s
# Epoch 043 | train 0.1397/0.9868 | val 0.2277/0.9390 | 1.38s <-- best saved
# Epoch 044 | train 0.1131/1.0000 | val 0.2323/0.9634 | 1.21s
# Epoch 045 | train 0.1076/0.9974 | val 0.2120/0.9390 | 1.50s <-- best saved
# Epoch 046 | train 0.1003/0.9947 | val 0.2392/0.9268 | 1.28s
# Epoch 047 | train 0.1018/0.9868 | val 0.2258/0.9390 | 1.31s
# Epoch 048 | train 0.0845/0.9974 | val 0.1671/0.9634 | 1.48s <-- best saved
# Epoch 049 | train 0.0801/0.9947 | val 0.2026/0.9512 | 1.22s
# Epoch 050 | train 0.0665/1.0000 | val 0.1753/0.9634 | 1.26s
# Epoch 051 | train 0.0576/0.9974 | val 0.1599/0.9512 | 1.31s <-- best saved
# Epoch 052 | train 0.0622/0.9947 | val 0.1775/0.9390 | 1.48s
# Epoch 053 | train 0.0489/0.9974 | val 0.2069/0.9390 | 1.26s
# Epoch 054 | train 0.0535/0.9947 | val 0.2039/0.9268 | 1.29s
# Epoch 055 | train 0.0518/0.9947 | val 0.1183/0.9512 | 1.31s <-- best saved
# Epoch 056 | train 0.0413/0.9974 | val 0.2286/0.9268 | 1.34s
# Epoch 057 | train 0.0440/0.9974 | val 0.1003/0.9634 | 1.41s <-- best saved
# Epoch 058 | train 0.0378/1.0000 | val 0.2122/0.9390 | 1.25s
# Epoch 059 | train 0.0415/0.9974 | val 0.1679/0.9390 | 1.22s
# Epoch 060 | train 0.0315/0.9974 | val 0.1512/0.9634 | 1.26s
# Epoch 061 | train 0.0360/0.9974 | val 0.1422/0.9634 | 1.43s
# Epoch 062 | train 0.0236/1.0000 | val 0.1351/0.9512 | 1.22s
# Epoch 063 | train 0.0238/0.9974 | val 0.1761/0.9390 | 1.29s
# Epoch 064 | train 0.0222/1.0000 | val 0.1415/0.9634 | 1.40s
# Epoch 065 | train 0.0204/1.0000 | val 0.1536/0.9390 | 1.91s
# Epoch 066 | train 0.0246/0.9974 | val 0.1334/0.9512 | 1.37s
# Epoch 067 | train 0.0188/1.0000 | val 0.1473/0.9512 | 1.35s
# Epoch 068 | train 0.0261/0.9974 | val 0.1340/0.9634 | 1.44s
# Epoch 069 | train 0.0207/0.9974 | val 0.1362/0.9634 | 1.45s
# Epoch 070 | train 0.0164/1.0000 | val 0.1373/0.9512 | 1.50s
# Epoch 071 | train 0.0166/1.0000 | val 0.1389/0.9512 | 1.38s
# Epoch 072 | train 0.0157/1.0000 | val 0.1369/0.9512 | 1.32s
# Epoch 073 | train 0.0166/1.0000 | val 0.1403/0.9512 | 1.59s
# Epoch 074 | train 0.0163/0.9974 | val 0.1326/0.9512 | 1.45s
# Epoch 075 | train 0.0149/1.0000 | val 0.1326/0.9512 | 1.32s
# Epoch 076 | train 0.0145/1.0000 | val 0.1328/0.9512 | 1.36s
# Early stopping at epoch 77
# Best epoch: 56
# Best val loss: 0.1003
# Last-5 Val Acc Avg: 0.9512
# Total training time: 2.28 minutes
# Average epoch time: 1.78 sec
# Model size: 2.73 MB

# %% [markdown]
# # Results

# %%
def _coerce_float_list(v):
    try:
        return [float(x) for x in (v if isinstance(v, (list, tuple)) else [])]
    except Exception:
        return []

def load_history_json(json_path):
    """Safe loader for train_history.json when you DO want to load from disk."""
    try:
        with open(json_path, "r") as f:
            hist = json.load(f)
        hist_out = {}
        for k in ("train_acc","val_acc","train_loss","val_loss"):
            hist_out[k] = _coerce_float_list(hist.get(k, []))
        return hist_out
    except Exception as e:
        print(f"[plot] Could not load history from {json_path}: {e}")
        return None

def plot_history(history=None, json_path=None, save_dir=None, title_suffix=""):
    """
    Plot accuracy & loss using decimals (0..1). Prefer `history` (in-memory).
    If `history` is None, tries to load from `json_path`.
    Titles have no run IDs.
    """
    if history is None:
        history = load_history_json(json_path)
    if not history:
        print("[plot] No history found to plot.")
        return

    train_acc = _coerce_float_list(history.get("train_acc"))
    val_acc   = _coerce_float_list(history.get("val_acc"))
    train_ls  = _coerce_float_list(history.get("train_loss"))
    val_ls    = _coerce_float_list(history.get("val_loss"))

    n = max(len(train_acc), len(val_acc), len(train_ls), len(val_ls))
    if n == 0:
        print("[plot] History lists are empty.")
        return
    epochs = list(range(1, n+1))

    def _pad(arr, n):
        arr = list(arr)
        if len(arr) < n:
            arr = arr + [np.nan]*(n-len(arr))
        return arr[:n]

    train_acc = _pad(train_acc, n)
    val_acc   = _pad(val_acc,   n)
    train_ls  = _pad(train_ls,  n)
    val_ls    = _pad(val_ls,    n)

    # --- Accuracy ---
    plt.figure(figsize=(7,4.5))
    plt.plot(epochs, train_acc, label="Train Acc")
    plt.plot(epochs, val_acc,   label="Val Acc")
    plt.xlabel("Epoch"); plt.ylabel("Accuracy (fraction)")
    plt.title("Accuracies" + (f" — {title_suffix}" if title_suffix else ""))
    plt.grid(True, alpha=0.3); plt.legend(loc="lower right")
    if save_dir:
        Path(save_dir).mkdir(parents=True, exist_ok=True)
        acc_path = str(Path(save_dir) / "acc_curve.png")
        plt.tight_layout(); plt.savefig(acc_path, dpi=150)
        print("[plot] Saved:", acc_path)
    plt.show()

    # --- Loss ---
    plt.figure(figsize=(7,4.5))
    plt.plot(epochs, train_ls, label="Train Loss")
    plt.plot(epochs, val_ls,   label="Val Loss")
    plt.xlabel("Epoch"); plt.ylabel("Loss")
    plt.title("Losses" + (f" — {title_suffix}" if title_suffix else ""))
    plt.grid(True, alpha=0.3); plt.legend(loc="upper right")
    if save_dir:
        loss_path = str(Path(save_dir) / "loss_curve.png")
        plt.tight_layout(); plt.savefig(loss_path, dpi=150)
        print("[plot] Saved:", loss_path)
    plt.show()

cands = glob.glob(os.path.join(CONFIG["EXPORT_DIR"], "run*", "train_history.json"))
if not cands:
    print("[plot] No train_history.json found under", CONFIG["EXPORT_DIR"])
else:
    json_path = max(cands, key=os.path.getmtime)
    save_dir  = os.path.dirname(json_path)
    print("[plot] Using history:", json_path)
    plot_history(history=None, json_path=json_path, save_dir=save_dir, title_suffix="Modified LSTM")
# Out:
# [plot] Using history: c:\Users\ACER NITRO\Documents\GitHub\FSL-PROJECT-DESIGN\BETTER\Training\Modified_LSTM\ModifiedLSTM_Exports\HybridLSTMGRU\20260302-225355\run17\train_history.json
# [plot] Saved: c:\Users\ACER NITRO\Documents\GitHub\FSL-PROJECT-DESIGN\BETTER\Training\Modified_LSTM\ModifiedLSTM_Exports\HybridLSTMGRU\20260302-225355\run17\acc_curve.png
# [plot] Saved: c:\Users\ACER NITRO\Documents\GitHub\FSL-PROJECT-DESIGN\BETTER\Training\Modified_LSTM\ModifiedLSTM_Exports\HybridLSTMGRU\20260302-225355\run17\loss_curve.png

# %%
def latest_ckpt(best_dir, prefix="run"):
    best_dir = Path(best_dir)
    if not best_dir.exists():
        return None, None
    cands = []
    for f in best_dir.iterdir():
        m = re.match(rf"^{re.escape(prefix)}(\d+)\.pt$", f.name)
        if m:
            cands.append((int(m.group(1)), f))
    if not cands:
        return None, None
    cands.sort(key=lambda x: x[0])
    return cands[-1]

BEST_DIR = CONFIG["BEST_DIR"]
run_id, ckpt_path = latest_ckpt(BEST_DIR)

assert ckpt_path is not None, f"No checkpoint found in {BEST_DIR}"

print(f"[eval] Loading checkpoint: {ckpt_path.name}")

checkpoint = torch.load(str(ckpt_path), map_location=device, weights_only=False)

saved_config = checkpoint["config"]

# Build model exactly as trained
test_model = build_modified_lstm(
    len(saved_config["CLASSES"]),
    input_size=saved_config["FEATURE_DIM"],
    hidden_size=saved_config["HIDDEN_SIZE"],
    num_layers=saved_config["NUM_LAYERS"],
    dropout=saved_config["DROPOUT"],
    use_layernorm=True
).to(device)

test_model.load_state_dict(checkpoint["model_state_dict"])
test_model.eval()

print(f"[eval] Loaded run {run_id:03d}")
print("Model params:",
      f"hidden={saved_config['HIDDEN_SIZE']},",
      f"layers={saved_config['NUM_LAYERS']},",
      f"dropout={saved_config['DROPOUT']}")

def _tta_variants(x_np, n_nonflip=3):
    T, D = x_np.shape
    FEAT = BASE_HAND_DIM
    coords = x_np[:, :FEAT].reshape(T, 42, 3).copy()
    extra = x_np[:, FEAT:].copy() if D > FEAT else None
    outs = [x_np.astype(np.float32)]
    for _ in range(n_nonflip):
        c = coords.copy()
        ang = np.deg2rad(np.random.uniform(-5, 5))
        R = np.array([[np.cos(ang), -np.sin(ang)], [np.sin(ang), np.cos(ang)]], np.float32)
        xy = c[..., :2].reshape(-1, 2) @ R.T
        c[..., :2] = xy.reshape(T, 42, 2)
        s = np.random.uniform(0.97, 1.05)
        c *= np.array([s, s, 1.0], np.float32)
        flat = np.concatenate([c.reshape(T, FEAT), extra], axis=1) if extra is not None else c.reshape(T, FEAT)
        outs.append(flat.astype(np.float32))
    return outs

FLAG_START, FLAG_END = CONFIG["FLAG_START"], CONFIG["FLAG_END"]
all_preds, all_labels = [], []

with torch.no_grad():
    for x, lens, y, _ in test_loader:
        B, T, D = x.shape
        x_np, y_np = x.cpu().numpy(), y.cpu().numpy()
        logits_sum = torch.zeros((B, len(CONFIG["CLASSES"])), device=device)
        for b in range(B):
            for v in _tta_variants(x_np[b]):
                v_t = torch.from_numpy(v).float().unsqueeze(0).to(device)
                rm = torch.from_numpy((v[:, FLAG_START:FLAG_END].sum(axis=1) > 0).astype(np.float32)).unsqueeze(0).to(device)
                logits_sum[b] += test_model(v_t, reset_mask=rm).squeeze(0)
        all_preds.append(logits_sum.argmax(1).cpu().numpy())
        all_labels.append(y_np)

all_preds, all_labels = np.concatenate(all_preds), np.concatenate(all_labels)
test_acc = (all_preds == all_labels).mean() * 100
print(f"TTA Test Accuracy: {test_acc:.2f}%")

labels_names = CONFIG["CLASSES"]
cm = confusion_matrix(all_labels, all_preds, labels=list(range(len(labels_names))))
fig, ax = plt.subplots(figsize=(9, 9))
disp = ConfusionMatrixDisplay(cm, display_labels=labels_names)
disp.plot(cmap="Blues", ax=ax, colorbar=False, values_format="d")
plt.xticks(rotation=60, ha="right", fontsize=8)
plt.yticks(fontsize=8)
plt.title(f"Confusion Matrix (TTA) — Run {run_id:03d} (Acc {test_acc:.2f}%)", pad=20)
plt.tight_layout()
cm_path = Path(CONFIG["EXPORT_DIR"]) / f"cm_tta_run{run_id:03d}.png"
plt.savefig(cm_path, dpi=200)
plt.show()

# --- 95 % CI and report ---
n = len(all_labels); p = test_acc / 100; z = 1.96
den = 1 + z*z/n
center = (p + z*z/(2*n)) / den
half = z * sqrt((p*(1-p)/n) + (z*z/(4*n*n))) / den
print(f"Test Acc 95% CI (Wilson): {(center-half)*100:.2f}% .. {(center+half)*100:.2f}%\n")
print("Classification Report:\n")
print(classification_report(all_labels, all_preds, target_names=labels_names, digits=3))
print("Saved confusion matrix to:", cm_path)
# Out:
# [eval] Loading checkpoint: run18.pt
# [eval] Loaded run 018
# Model params: hidden=212, layers=2, dropout=0.3
# TTA Test Accuracy: 97.56%
# Test Acc 95% CI (Wilson): 91.54% .. 99.33%
#
# Classification Report:
#
#                            precision    recall  f1-score   support
#
#               Color_Black      1.000     1.000     1.000         3
#                Color_Blue      1.000     1.000     1.000         3
#               Color_Green      1.000     1.000     1.000         3
#              Color_Orange      1.000     1.000     1.000         3
#                Color_Pink      1.000     1.000     1.000         3
#                 Color_Red      1.000     1.000     1.000         3
#               Color_White      1.000     1.000     1.000         3
#              Color_Yellow      1.000     1.000     1.000         3
#           Family_Daughter      1.000     1.000     1.000         3
#             Family_Father      1.000     1.000     1.000         3
#        Family_Grandfather      1.000     1.000     1.000         3
#        Family_Grandmother      1.000     1.000     1.000         3
#             Family_Mother      1.000     1.000     1.000         3
#                Family_Son      1.000     1.000     1.000         3
#              Numbers_Five      1.000     1.000     1.000         3
#              Numbers_Four      1.000     1.000     1.000         3
#               Numbers_One      1.000     1.000     1.000         3
#             Numbers_Three      1.000     1.000     1.000         3
#               Numbers_Two      0.750     1.000     0.857         3
#          Relationship_Boy      1.000     0.667     0.800         3
#         Relationship_Girl      0.667     0.667     0.667         3
#          Survival_Correct      1.000     1.000     1.000         4
# Survival_Don't Understand      1.000     1.000     1.000         3
#               Survival_No      1.000     1.000     1.000         3
#       Survival_Understand      1.000     1.000     1.000         3
#            Survival_Wrong      1.000     1.000     1.000         3
#              Survival_Yes      1.000     1.000     1.000         3
#
#                  accuracy                          0.976        82
#                 macro avg      0.978     0.975     0.975        82
#              weighted avg      0.979     0.976     0.975        82
#
# Saved confusion matrix to: c:\Users\ACER NITRO\Documents\GitHub\FSL-PROJECT-DESIGN\BETTER\Training\Modified_LSTM\ModifiedLSTM_Exports\HybridLSTMGRU\20260302-225355\cm_tta_run018.png

# %%
def latest_ckpt(best_dir, prefix="run"):
    best_dir = Path(best_dir)
    if not best_dir.exists():
        return None, None

    candidates = []
    for f in best_dir.iterdir():
        m = re.match(rf"^{re.escape(prefix)}(\d+)\.(pt|pth)$", f.name)
        if m:
            candidates.append((int(m.group(1)), f))

    if not candidates:
        return None, None

    candidates.sort(key=lambda x: x[0])
    return candidates[-1]


# --- locate latest checkpoint ---
BEST_DIR = CONFIG["BEST_DIR"]
run_id, ckpt_path = latest_ckpt(BEST_DIR)
assert ckpt_path is not None, f"No checkpoint found under {BEST_DIR}"

print(f"[eval] Loading checkpoint: {ckpt_path.name}")


# --- load safely (PyTorch 2.6 fix) ---
checkpoint = torch.load(
    str(ckpt_path),
    map_location=device,
    weights_only=False
)

# determine format
if isinstance(checkpoint, dict) and "model_state_dict" in checkpoint:
    state_dict = checkpoint["model_state_dict"]
    saved_config = checkpoint["config"]
else:
    # pure .pth weights only
    state_dict = checkpoint
    saved_config = CONFIG  # fallback


# --- rebuild model using saved hyperparameters ---
test_model = build_modified_lstm(
    len(saved_config["CLASSES"]),
    input_size=saved_config["FEATURE_DIM"],
    hidden_size=saved_config["HIDDEN_SIZE"],
    num_layers=saved_config["NUM_LAYERS"],
    dropout=saved_config["DROPOUT"],
    use_layernorm=True
).to(device)

test_model.load_state_dict(state_dict)
test_model.eval()

print(
    f"[eval] Run {run_id:03d} | "
    f"hidden={saved_config['HIDDEN_SIZE']} | "
    f"layers={saved_config['NUM_LAYERS']} | "
    f"dropout={saved_config['DROPOUT']}"
)


# --- evaluate ---
FLAG_START, FLAG_END = saved_config["FLAG_START"], saved_config["FLAG_END"]

all_preds, all_labels = [], []

with torch.no_grad():
    for x, lens, y, _ in test_loader:
        x, y = x.to(device).float(), y.to(device).long()
        reset_mask = (x[..., FLAG_START:FLAG_END].sum(dim=-1) > 0).float()
        logits = test_model(x, reset_mask=reset_mask)

        all_preds.append(logits.argmax(1).cpu().numpy())
        all_labels.append(y.cpu().numpy())

all_preds = np.concatenate(all_preds)
all_labels = np.concatenate(all_labels)

acc = (all_preds == all_labels).mean() * 100
print(f"\nPlain Test Accuracy: {acc:.2f}%")


# --- confusion matrix ---
labels_names = saved_config["CLASSES"]
cm = confusion_matrix(all_labels, all_preds, labels=list(range(len(labels_names))))

fig, ax = plt.subplots(figsize=(9, 9))
disp = ConfusionMatrixDisplay(cm, display_labels=labels_names)
disp.plot(cmap="Blues", ax=ax, colorbar=False, values_format="d")

plt.xticks(rotation=60, ha="right", fontsize=8)
plt.yticks(fontsize=8)
plt.title(f"Confusion Matrix — Run {run_id:03d} (Acc {acc:.2f}%)", pad=20)
plt.tight_layout()

cm_path = Path(CONFIG["EXPORT_DIR"]) / f"cm_plain_run{run_id:03d}.png"
plt.savefig(cm_path, dpi=200)
plt.show()

print("\nClassification Report:\n")
print(classification_report(all_labels, all_preds, target_names=labels_names, digits=3))
print("Saved confusion matrix to:", cm_path)
# Out:
# [eval] Loading checkpoint: run18.pth
# [eval] Run 018 | hidden=212 | layers=2 | dropout=0.3
#
# Plain Test Accuracy: 97.56%
# Classification Report:
#
#                            precision    recall  f1-score   support
#
#               Color_Black      1.000     1.000     1.000         3
#                Color_Blue      1.000     1.000     1.000         3
#               Color_Green      1.000     1.000     1.000         3
#              Color_Orange      1.000     1.000     1.000         3
#                Color_Pink      1.000     1.000     1.000         3
#                 Color_Red      1.000     1.000     1.000         3
#               Color_White      1.000     1.000     1.000         3
#              Color_Yellow      1.000     1.000     1.000         3
#           Family_Daughter      1.000     1.000     1.000         3
#             Family_Father      1.000     1.000     1.000         3
#        Family_Grandfather      1.000     1.000     1.000         3
#        Family_Grandmother      1.000     1.000     1.000         3
#             Family_Mother      1.000     1.000     1.000         3
#                Family_Son      1.000     1.000     1.000         3
#              Numbers_Five      1.000     1.000     1.000         3
#              Numbers_Four      1.000     1.000     1.000         3
#               Numbers_One      1.000     1.000     1.000         3
#             Numbers_Three      1.000     1.000     1.000         3
#               Numbers_Two      0.750     1.000     0.857         3
#          Relationship_Boy      1.000     0.667     0.800         3
#         Relationship_Girl      0.667     0.667     0.667         3
#          Survival_Correct      1.000     1.000     1.000         4
# Survival_Don't Understand      1.000     1.000     1.000         3
#               Survival_No      1.000     1.000     1.000         3
#       Survival_Understand      1.000     1.000     1.000         3
#            Survival_Wrong      1.000     1.000     1.000         3
#              Survival_Yes      1.000     1.000     1.000         3
#
#                  accuracy                          0.976        82
#                 macro avg      0.978     0.975     0.975        82
#              weighted avg      0.979     0.976     0.975        82
#
# Saved confusion matrix to: c:\Users\ACER NITRO\Documents\GitHub\FSL-PROJECT-DESIGN\BETTER\Training\Modified_LSTM\ModifiedLSTM_Exports\HybridLSTMGRU\20260302-225355\cm_plain_run018.png
